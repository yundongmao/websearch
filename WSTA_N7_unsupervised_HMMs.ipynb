# %% [markdown]
# # POS tagging on Twitter

# %% [markdown]
# *Notebook for COMP90042, Web search and Text Analysis*
#
# *Copyright The University of Melbourne, 2018*

# %% [markdown]
# In this notebook we will check the performance of the POS tagger from the last workshop on a different domain: Twitter. First, let's build the HMM tagger again.

# %%
import numpy as np
from nltk.corpus import treebank
corpus = treebank.tagged_sents()

word_numbers = {}
tag_numbers = {}

num_corpus = []
for sent in corpus:
    num_sent = []
    for word, tag in sent:
        wi = word_numbers.setdefault(word.lower(), len(word_numbers))
        ti = tag_numbers.setdefault(tag, len(tag_numbers))
        num_sent.append((wi, ti))
    num_corpus.append(num_sent)
    
word_names = [None] * len(word_numbers)
for word, index in word_numbers.items():
    word_names[index] = word
tag_names = [None] * len(tag_numbers)
for tag, index in tag_numbers.items():
    tag_names[index] = tag
    
S = len(tag_numbers)
V = len(word_numbers)

# initalise
eps = 0.1
pi = eps * np.ones(S)
A = eps * np.ones((S, S))
O = eps * np.ones((S, V))

# count
for sent in num_corpus:
    last_tag = None
    for word, tag in sent:
        O[tag, word] += 1
        if last_tag == None:
            pi[tag] += 1
        else:
            A[last_tag, tag] += 1
        last_tag = tag
        
# normalise
pi /= np.sum(pi)
for s in range(S):
    O[s,:] /= np.sum(O[s,:])
    A[s,:] /= np.sum(A[s,:])
    
    
def viterbi(params, observations):
    pi, A, O = params
    M = len(observations)
    S = pi.shape[0]
    
    alpha = np.zeros((M, S))
    alpha[:,:] = float('-inf')
    backpointers = np.zeros((M, S), 'int')
    
    # base case
    alpha[0, :] = pi * O[:,observations[0]]
    
    # recursive case
    for t in range(1, M):
        for s2 in range(S):
            for s1 in range(S):
                score = alpha[t-1, s1] * A[s1, s2] * O[s2, observations[t]]
                if score > alpha[t, s2]:
                    alpha[t, s2] = score
                    backpointers[t, s2] = s1
    
    # now follow backpointers to resolve the state sequence
    ss = []
    ss.append(np.argmax(alpha[M-1,:]))
    for i in range(M-1, 0, -1):
        ss.append(backpointers[i, ss[-1]])
        
    return list(reversed(ss)), np.max(alpha[M-1,:])

# %% [markdown]
# ## Reading a corpus of POS tagged tweets

# %% [markdown]
# Remember from the lecture: we always need some annotated data in order to evaluate our methods, even when they are unsupervised. In order to do this, we will use a dataset of tweets annotated with POS tags, which we will download automatically via Python.
#
# The next step is to read the file. We will use it as a *test set* only: you are not allowed to use any of this data for training.

# %%
import urllib
urllib.urlretrieve("https://github.com/aritter/twitter_nlp/raw/master/data/annotated/pos.txt","pos.txt")

test_inputs = []
test_outputs = []
with open('pos.txt') as f:
    words = []
    pos_tags = []
    for line in f:
        
        if line.strip() == '':
#             print line
            test_inputs.append(words)
            test_outputs.append(pos_tags)
            words = []
            pos_tags = []
        else:
            print line
#             print line.strip()
            word, pos = line.strip().split()
#             print word,pos
            words.append(word)
            pos_tags.append(pos)
print len(test_inputs)
print test_inputs[0]
print test_outputs[0]
# Out:
# @paulwalk USR
#
# It PRP
#
# 's VBZ
#
# the DT
#
# view NN
#
# from IN
#
# where WRB
#
# I PRP
#
# 'm VBP
#
# living VBG
#
# for IN
#
# two CD
#
# weeks NNS
#
# . .
#
# Empire NNP
#
# State NNP
#
# Building NNP
#
# = SYM
#
# ESB NNP
#
# . .
#
# Pretty RB
#
# bad JJ
#
# storm NN
#
# here RB
#
# last JJ
#
# evening NN
#
# . .
#
# Small JJ
#
# Biz NNP
#
# Tech NNP
#
# Tour NNP
#
# 2010 CD
#
# Launches VBZ
#
# Five CD
#
# City NN
#
# Tour NN
#
# MONTCLAIR NNP
#
# N.J. NNP
#
# ...: :
#
# The DT
#
# all DT
#
# day NN
#
# event NN
#
# features VBZ
#
# America's... NNP
#
# http://tinyurl.com/28hd9fu URL
#
# #fb HT
#
# @MiSS_SOTO USR
#
# I PRP
#
# think VBP
#
# that DT
#
# 's VBZ
#
# when WRB
#
# I PRP
#
# 'm VBP
#
# gonna VBG
#
# be VB
#
# there RB
#
# On IN
#
# Thanksgiving NNP
#
# after IN
#
# you PRP
#
# done VBN
#
# eating VBG
#
# its PRP
#
# #TimeToGetOut HT
#
# unless IN
#
# you PRP
#
# wanna VBP
#
# help VB
#
# with IN
#
# the DT
#
# dishes NNS
#
# RT RT
#
# @robmoysey USR
#
# Eyeopener NNP
#
# vs CC
#
# . .
#
# Ryerson NNP
#
# Quidditch NN
#
# team NN
#
# this DT
#
# Sunday NNP
#
# at IN
#
# 4 CD
#
# p.m. NN
#
# Anyone NN
#
# know VB
#
# where WRB
#
# to TO
#
# get VB
#
# cheap JJ
#
# brooms NNS
#
# ? .
#
# #Ryerson HT
#
# @RUQuidditch USR
#
# #Rams HT
#
# RT RT
#
# @ZodiacFacts USR
#
# : :
#
# #ZodiacFacts HT
#
# As IN
#
# an DT
#
# #Aries HT
#
# romance NN
#
# is VBZ
#
# n't RB
#
# about IN
#
# what WP
#
# you PRP
#
# 're VBP
#
# after IN
#
# -- :
#
# it PRP
#
# 's VBZ
#
# about IN
#
# taking VBG
#
# chances NNS
#
# , ,
#
# exploring VBG
#
# and CC
#
# keeping VBG
#
# an DT
#
# ... :
#
# ThAnK VB
#
# gOd NNP
#
# ItS PRP
#
# fRiDaY NNP
#
# !! .
#
# I PRP
#
# think VBP
#
# that DT
#
# today NN
#
# the DT
#
# party NN
#
# has VBZ
#
# been VBN
#
# canceled VBN
#
# makes VBZ
#
# too RB
#
# much RB
#
# air NN
#
# in IN
#
# the DT
#
# street NN
#
# loll UH
#
# . .
#
# miss VBP
#
# u PRP
#
# twitfriends NNS
#
# . .
#
# xx UH
#
# Gotta VBP
#
# dress VB
#
# up RP
#
# for IN
#
# london NNP
#
# fashion NN
#
# week NN
#
# and CC
#
# party VB
#
# in IN
#
# style NN
#
# ! .
#
# @rattleknackers USR
#
# amusing JJ
#
# ? .
#
# This DT
#
# is VBZ
#
# some DT
#
# of IN
#
# the DT
#
# greatest JJS
#
# music NN
#
# of IN
#
# all DT
#
# time NN
#
# , ,
#
# my PRP$
#
# foot NN
#
# has VBZ
#
# n't RB
#
# stopped VBN
#
# tapping VBG
#
# all DT
#
# night NN
#
# @aplusk USR
#
# http://www.youtube.com/watch?v=eLMui7zBiXo URL
#
# we PRP
#
# beat VBD
#
# kilkenny NNP
#
# after IN
#
# they PRP
#
# beat VBD
#
# us PRP
#
# for IN
#
# the DT
#
# last JJ
#
# 4 CD
#
# years NNS
#
# in IN
#
# the DT
#
# hurling NN
#
# . .
#
# Woo UH
#
# !!! .
#
# @MakethisRalate USR
#
# good JJ
#
# luck NN
#
# at IN
#
# Elliot NNP
#
# Miner NNP
#
# :D UH
#
# yous PRP
#
# were VBD
#
# greaaaat JJ
#
# tonight NN
#
# &lt; UH
#
# 3 UH
#
# xx UH
#
# @snufflesgirl25 USR
#
# @mo9x USR
#
# Well UH
#
# . .
#
# just RB
#
# beg VB
#
# @100monkeysmusic USR
#
# .. :
#
# PLEASE VB
#
# come VB
#
# to TO
#
# the DT
#
# #SBLeurope HT
#
# Next JJ
#
# year NN
#
# !. :
#
# We PRP
#
# need VBP
#
# you PRP
#
# there RB
#
# ! .
#
# *puss NN
#
# in IN
#
# boots NNS
#
# eyes* NNS
#
# Kk UH
#
# its PRP
#
# 22:48 CD
#
# friday NNP
#
# nyt NN
#
# :D UH
#
# really RB
#
# tired JJ
#
# so IN
#
# imma PRP
#
# go VB
#
# to TO
#
# sleep VB
#
# :) UH
#
# good JJ
#
# nyt NN
#
# x UH
#
# god NNP
#
# bles VBZ
#
# xxxxx UH
#
# @ConorMc_Ginty USR
#
# GaGa NNP
#
# played VBD
#
# here RB
#
# a DT
#
# few JJ
#
# weeks NNS
#
# back JJ
#
# . .
#
# She PRP
#
# spoke VBD
#
# out RP
#
# against IN
#
# SB1070 NNP
#
# during IN
#
# the DT
#
# show NN
#
# . .
#
# God NNP
#
# bless VBZ
#
# her PRP
#
# for IN
#
# that DT
#
# . .
#
# @DaylySpecialz USR
#
# im PRP
#
# doin VBG
#
# good JJ
#
# , ,
#
# just RB
#
# maxin VBG
#
# & CC
#
# relaxin VBG
#
# on IN
#
# my PRP$
#
# day NN
#
# off IN
#
# ... :
#
# i PRP
#
# have VBP
#
# a DT
#
# 4 CD
#
# day NN
#
# stetch NN
#
# startin VBG
#
# tomorrow NN
#
# . .
#
# I PRP
#
# just RB
#
# took VBD
#
# " ''
#
# After IN
#
# getting VBG
#
# trampled VBD
#
# at IN
#
# a DT
#
# Justin NNP
#
# Bieber NNP
#
# concert NN
#
# , ,
#
# yoiu PRP
#
# wake VBP
#
# up IN
#
# and CC
#
# ..." ''
#
# and CC
#
# got VBD
#
# : :
#
# Part NN
#
# 6 CD
#
# :) UH
#
# ! .
#
# Try VB
#
# it PRP
#
# : :
#
# http://tinyurl.com/26zeju5 URL
#
# @k8_walsh USR
#
# I PRP
#
# 've VBP
#
# been VBN
#
# out IN
#
# of IN
#
# the DT
#
# loop NN
#
# , ,
#
# but CC
#
# is VBZ
#
# Private NNP
#
# Practice NNP
#
# coming VBG
#
# back RB
#
# this DT
#
# year NN
#
# ? .
#
# I PRP
#
# just RB
#
# took VBD
#
# " ''
#
# After IN
#
# getting VBG
#
# trampled VBD
#
# at IN
#
# a DT
#
# Justin NNP
#
# Bieber NNP
#
# concert NN
#
# , ,
#
# yoiu PRP
#
# wake VBP
#
# up IN
#
# and CC
#
# ..." CD
#
# and CC
#
# got VBD
#
# : :
#
# Part NN
#
# 6 CD
#
# :) UH
#
# ! .
#
# Try VB
#
# it PRP
#
# : :
#
# http://tinyurl.com/233u5lu URL
#
# RT RT
#
# @Mickey__Rourke USR
#
# : :
#
# 58 CD
#
# years NNS
#
# ago IN
#
# today NN
#
# I PRP
#
# tumbled VBD
#
# from IN
#
# my PRP$
#
# mother NN
#
# 's POS
#
# womb NN
#
# with IN
#
# a DT
#
# cigarette NN
#
# in IN
#
# my PRP$
#
# mouth NN
#
# and CC
#
# a DT
#
# chihuahua NN
#
# puppy NN
#
# under IN
#
# each DT
#
# arm NN
#
# ... :
#
# Amazon NNP
#
# U.K. NNP
#
# Offering VBG
#
# HTC NNP
#
# Desire NNP
#
# Z NNP
#
# Unlocked JJ
#
# October NNP
#
# 11 CD
#
# : :
#
# We PRP
#
# just RB
#
# got VBD
#
# official JJ
#
# word NN
#
# of IN
#
# the DT
#
# HTC NNP
#
# Desire NNP
#
# Z NNP
#
# earlier JJR
#
# in IN
#
# Lo NNP
#
# ... :
#
# http://bit.ly/bsyz9H URL
#
# Yay UH
#
# . .
#
# @penguin USR
#
# is VBZ
#
# coming VBG
#
# to TO
#
# see VB
#
# me PRP
#
# next JJ
#
# week NN
#
# ... :
#
# plotting VBG
#
# my PRP$
#
# cooking NN
#
# now RB
#
# ! .
#
# RT RT
#
# @m_candelaria USR
#
# : :
#
# The DT
#
# amazing JJ
#
# Follow NNP
#
# Friday NNP
#
# Train NNP
#
# : :
#
# @Sketchjobs USR
#
# @lollieshopping USR
#
# @philadelphiabn USR
#
# @elainebiss USR
#
# @TableMatters10 USR
#
# @STALKmyPRETT USR
#
# ... :
#
# RT RT
#
# @JDay_Sept15 USR
#
# : :
#
# RT RT
#
# @Ashanie_di_Don USR
#
# : :
#
# @JDay_Sept15 USR
#
# lol UH
#
# i PRP
#
# see VBP
#
# someone NN
#
# hyped JJ
#
# and CC
#
# ready JJ
#
# for IN
#
# #FlavaFridays HT
#
# tonight NN
#
# &lt; CC
#
# every DT
#
# week NN
#
# . .
#
# Lets VBP
#
# get VB
#
# it PRP
#
# ! .
#
# @BieberEgypt USR
#
# I PRP
#
# 've VBP
#
# got VBN
#
# some DT
#
# bad JJ
#
# news NN
#
# , ,
#
# Yeah UH
#
# I PRP
#
# cant MD
#
# come VB
#
# to TO
#
# the DT
#
# meeting NN
#
# tomorrow NN
#
# . .
#
# : :
#
# S NNP
#
# What WP
#
# a DT
#
# productive JJ
#
# day NN
#
# . .
#
# Not RB
#
# . .
#
# Fellas NNS
#
# Do VB
#
# n't RB
#
# just RB
#
# lick VB
#
# the DT
#
# PussyY NN
#
# , ,
#
# LOVE VB
#
# IT PRP
#
# ! .
#
# enjoy VB
#
# it PRP
#
# . .
#
# like IN
#
# u PRP
#
# just RB
#
# got VBD
#
# married VBN
#
# & CC
#
# the DT
#
# preacher NN
#
# said VBD
#
# u PRP
#
# may MD
#
# kiss VB
#
# the DT
#
# bride NN
#
# RT RT
#
# @ItsTheTeenLife USR
#
# : :
#
# The DT
#
# exact JJ
#
# day NN
#
# that IN
#
# I PRP
#
# wear VBP
#
# shorts NNS
#
# and CC
#
# a DT
#
# tee NN
#
# shirt NN
#
# everyone NN
#
# shows VBZ
#
# up RP
#
# wearing VBG
#
# hoodies NNS
#
# and CC
#
# jeans NNS
#
# . .
#
# -_- UH
#
# #ItsTheTeenLife HT
#
# RT RT
#
# @BieberPledge USR
#
# : :
#
# When WRB
#
# I PRP
#
# Get VBP
#
# Old JJ
#
# , ,
#
# Imma PRP
#
# Still RB
#
# Be VB
#
# Rockin VBG
#
# Out RP
#
# To TO
#
# ' ''
#
# Baby'...Even NNP
#
# If IN
#
# I PRP
#
# Break VBP
#
# A DT
#
# Hip NN
#
# ;) UH
#
# I PRP
#
# just RB
#
# took VBD
#
# " ''
#
# When WRB
#
# your PRP$
#
# mom NN
#
# makes VBZ
#
# you PRP
#
# go VBP
#
# live VB
#
# with IN
#
# your PRP$
#
# dad NN
#
# Scooter NNP
#
# Braun NNP
#
# , ,
#
# your PRP$
#
# life NN
#
# ..." ''
#
# and CC
#
# got VBD
#
# : :
#
# Part NN
#
# 7 CD
#
# ! .
#
# Try VB
#
# it PRP
#
# : :
#
# http://tinyurl.com/27r2pdz URL
#
# Not RB
#
# feeling VBG
#
# up IN
#
# to TO
#
# par NN
#
# today NN
#
# . .
#
# #stressing HT
#
# Thanks UH
#
# and CC
#
# I PRP
#
# will MD
#
# RT RT
#
# @InnerGizerBunni USR
#
# @kizfoprez_TR USR
#
# Happy JJ
#
# Berlated JJ
#
# Birthday NN
#
# ! .
#
# I PRP
#
# hope VBP
#
# u PRP
#
# have VBP
#
# fun JJ
#
# & CC
#
# live VBP
#
# it PRP
#
# up RP
#
# tonight NN
#
# .. :
#
# Enjoy VB
#
# & CC
#
# b VB
#
# safe JJ
#
# ! .
#
# Man UH
#
# i PRP
#
# been VBP
#
# eatin VBG
#
# fastfood NN
#
# everyday NN
#
# im PRP
#
# so RB
#
# glad JJ
#
# my PRP$
#
# mommy NN
#
# cookin VBG
#
# today NN
#
# ... :
#
# Gotta VBP
#
# call VB
#
# mom NN
#
# 2 TO
#
# let VB
#
# her PRP
#
# know VBP
#
# it PRP
#
# 's VBZ
#
# almost RB
#
# 3 CD
#
# . .
#
# Yli NNP
#
# gets VBZ
#
# out RP
#
# in IN
#
# 15 CD
#
# . .
#
# Mom NN
#
# took VBD
#
# the DT
#
# antenna NN
#
# home NN
#
# today NN
#
# & CC
#
# connected VBD
#
# it PRP
#
# at IN
#
# home NN
#
# , ,
#
# finally RB
#
# . .
#
# @Zerinaakers USR
#
# talking VBG
#
# about IN
#
# as RB
#
# far RB
#
# as IN
#
# shooting VBG
#
# for IN
#
# location NN
#
# its PRP
#
# going VBG
#
# to TO
#
# be VB
#
# on IN
#
# #Vh1 HT
#
# so RB
#
# by IN
#
# the DT
#
# end NN
#
# of IN
#
# the DT
#
# month NN
#
# i PRP
#
# should MD
#
# know VB
#
# something NN
#
# Really RB
#
# hope VBP
#
# I PRP
#
# can MD
#
# get VB
#
# to TO
#
# @glasgowfilm USR
#
# for IN
#
# Winter NNP
#
# 's POS
#
# Bone NNP
#
# - :
#
# need VBP
#
# to TO
#
# get VB
#
# on IN
#
# with IN
#
# job NN
#
# applications NNS
#
# tonight NN
#
# then RB
#
# ! .
#
# Trailer NN
#
# : :
#
# http://bit.ly/bhUlum URL
#
# @CWWatson USR
#
# one CD
#
# of IN
#
# the DT
#
# complainers NNS
#
# is VBZ
#
# a DT
#
# child NN
#
# minder NN
#
# who WP
#
# brings VBZ
#
# kids NNS
#
# to TO
#
# the DT
#
# school NN
#
# then RB
#
# looks VBZ
#
# after RP
#
# other JJ
#
# kids NNS
#
# thro IN
#
# the DT
#
# day NN
#
# . .
#
# Beggers NNS
#
# belief NN
#
# Bonfire NN
#
# tonite NN
#
# . .
#
# All DT
#
# are VBZ
#
# welcome VB
#
# , ,
#
# joe NNP
#
# included VBD
#
# @zombie_killer94 USR
#
# aaahh UH
#
# sorry JJ
#
# i PRP
#
# posted VBD
#
# the DT
#
# link NN
#
# wrong JJ
#
# :( UH
#
# basically RB
#
# their PRP$
#
# record NN
#
# company NN
#
# confirmed VBD
#
# the DT
#
# title NN
#
# & CC
#
# it PRP
#
# comes VBZ
#
# out IN
#
# nov NNP
#
# 23 CD
#
# XD UH
#
# Happy JJ
#
# birfday NN
#
# to TO
#
# the DT
#
# only JJ
#
# p-i-m-p NN
#
# I PRP
#
# know VBP
#
# ... :
#
# @amcdavid USR
#
# ! .
#
# We PRP
#
# 're VBP
#
# getting VBG
#
# " ''
#
# white JJ
#
# boy NN
#
# wasted VBN
#
# " ''
#
# tonight NN
#
# ! .
#
# @endlesskies USR
#
# ik UH
#
# me PRP
#
# 2 RB
#
# . .
#
# At IN
#
# night NN
#
# I PRP
#
# 'm VBP
#
# wide RB
#
# awake JJ
#
# but CC
#
# the DT
#
# daytime NN
#
# , ,
#
# I PRP
#
# 'm VBP
#
# so RB
#
# tired JJ
#
# my PRP$
#
# day NN
#
# drags VBZ
#
# Is VBZ
#
# Joaquin NNP
#
# Phoenix NNP
#
# Our PRP$
#
# Modern JJ
#
# Day NN
#
# Andy NNP
#
# Kaufman NNP
#
# ?: .
#
# ... :
#
# the DT
#
# bizarre JJ
#
# events NNS
#
# leading VBG
#
# up IN
#
# to TO
#
# this DT
#
# moment NN
#
# , ,
#
# the DT
#
# movie NN
#
# could MD
#
# ... :
#
# http://bit.ly/aUZ2on URL
#
# Not RB
#
# only RB
#
# is VBZ
#
# it PRP
#
# #BattlestarGalactica HT
#
# 's POS
#
# 32nd JJ
#
# Anniversary NN
#
# , ,
#
# tonite NN
#
# is VBZ
#
# the DT
#
# 3rd JJ
#
# season NN
#
# premiere NN
#
# of IN
#
# #StarWars HT
#
# #TheCloneWars HT
#
# !! .
#
# even RB
#
# better JJR
#
# than IN
#
# cocktail NN
#
# friday NNP
#
# ! .
#
# http://is.gd/ffDb9 URL
#
# @_AsToldByBV USR
#
# well UH
#
# i PRP
#
# wrote VBD
#
# you PRP
#
# like IN
#
# 6 CD
#
# times NNS
#
# this DT
#
# week NN
#
# ! .
#
# urgh UH
#
# . .
#
# RACHELLE NNP
#
# im PRP
#
# gonnauh VBG
#
# kill VB
#
# YOU PRP
#
# tonite NN
#
# ! .
#
# I PRP
#
# want VBP
#
# it PRP
#
# NOW RB
#
# ! .
#
# ;) UH
#
# RT RT
#
# : :
#
# @corsairartisan USR
#
# Pumpkin NNP
#
# Moonshine NNP
#
# has VBZ
#
# arrived VBN
#
# in IN
#
# Nashville NNP
#
# -- :
#
# Give VB
#
# it PRP
#
# a DT
#
# week NN
#
# to TO
#
# get VB
#
# it PRP
#
# in IN
#
# stores NNS
#
# . .
#
# KY NNP
#
# ships VBZ
#
# next IN
#
# week NN
#
# ! .
#
# Hey UH
#
# .... :
#
# my PRP$
#
# birthday NN
#
# is VBZ
#
# in IN
#
# exactly RB
#
# one CD
#
# month NN
#
# !!! .
#
# :D UH
#
# RT RT
#
# @TheOutlawz USR
#
# : :
#
# EVERYBODY NN
#
# WHO WP
#
# WANT VBZ
#
# A DT
#
# FOLLOW NN
#
# FROM IN
#
# ME PRP
#
# FOR IN
#
# FOLLOW NN
#
# FRIDAY NNP
#
# LET VB
#
# ME PRP
#
# KNOW VBP
#
# !! .
#
# WE PRP
#
# AINT VBP
#
# LIKE IN
#
# THESE DT
#
# HOLLYWOOD NNP
#
# AZZ NN
#
# RAPPERS NNS
#
# WE PRP
#
# FOLLOW VBP
#
# BACK RB
#
# ! .
#
# RT RT
#
# @rockerfuckerak USR
#
# : :
#
# What WP
#
# 's VBZ
#
# done VBN
#
# is VBZ
#
# done VBN
#
# , ,
#
# Just RB
#
# leave VBP
#
# it PRP
#
# alone RB
#
# , ,
#
# and CC
#
# do VB
#
# n't RB
#
# regret VB
#
# . .
#
# Sometimes RB
#
# somethings NNS
#
# turn VBP
#
# in-to IN
#
# dumb JJ
#
# things NNS
#
# . .
#
# And CC
#
# that DT
#
# 's VBZ
#
# when WRB
#
# ... :
#
# @ShelAndPushPlay USR
#
# Yeah UH
#
# man UH
#
# , ,
#
# u PRP
#
# got VBD
#
# it PRP
#
# . .
#
# It PRP
#
# 's VBZ
#
# only RB
#
# a DT
#
# matter NN
#
# of IN
#
# time NN
#
# . .
#
# @jaredleto USR
#
# ... :
#
# ive PRP
#
# been VBN
#
# to TO
#
# 13 CD
#
# 30stm NNP
#
# concerts NNS
#
# now RB
#
# and CC
#
# you PRP
#
# never RB
#
# got VBD
#
# me PRP
#
# on IN
#
# stage NN
#
# during/before RB
#
# kings NNP
#
# and CC
#
# queens NNPS
#
# :( UH
#
# (( UH
#
# looking VBG
#
# forward RB
#
# to TO
#
# a DT
#
# weekend NN
#
# resting VBG
#
# foot NN
#
# !! .
#
# oh UH
#
# and CC
#
# the DT
#
# irish NNP
#
# on IN
#
# sunday NNP
#
# . .
#
# Power NN
#
# nap NN
#
# . .
#
# I PRP
#
# need VBP
#
# it PRP
#
# . .
#
# Its PRP
#
# been VBN
#
# a DT
#
# stressful JJ
#
# week NN
#
# . .
#
# I PRP
#
# 'm VBP
#
# excited VBD
#
# for IN
#
# xmas NNP
#
# , ,
#
# haha UH
#
# . .
#
# Goodnight UH
#
# . .
#
# :) UH
#
# today NN
#
# just RB
#
# does VBZ
#
# n't RB
#
# feel VB
#
# like IN
#
# a DT
#
# Friday NNP
#
# Yahoo NNP
#
# : :
#
# Jackie NNP
#
# joins VBZ
#
# Twitter NNP
#
# 50 CD
#
# years NNS
#
# after IN
#
# JFK NNP
#
# campaign NN
#
# : :
#
# Had VBD
#
# Twitter NNP
#
# been VBN
#
# an DT
#
# option NN
#
# in IN
#
# 1960 CD
#
# , ,
#
# a DT
#
# pregnant JJ
#
# Jacquelin NNP
#
# ... :
#
# http://yhoo.it/9VAD4A URL
#
# my PRP$
#
# past NN
#
# was VBD
#
# the DT
#
# reason NN
#
# i PRP
#
# tried VBD
#
# to TO
#
# kill VB
#
# myself PRP
#
# the DT
#
# other JJ
#
# day NN
#
# , ,
#
# and CC
#
# i PRP
#
# 'll MD
#
# gladly RB
#
# do VB
#
# it PRP
#
# again RB
#
# . .
#
# Dollar NN
#
# steady RB
#
# versus CC
#
# yen NN
#
# but CC
#
# market NN
#
# wary JJ
#
# of IN
#
# intervention NN
#
# | :
#
# Money NN
#
# ...: :
#
# The DT
#
# dollar NN
#
# held VBD
#
# near IN
#
# its PRP$
#
# highest JJS
#
# in IN
#
# a DT
#
# month NN
#
# ... :
#
# http://bit.ly/a0F3dO URL
#
# :( UH
#
# RT RT
#
# @themaine USR
#
# Who WP
#
# is VBZ
#
# coming VBG
#
# to TO
#
# the DT
#
# show NN
#
# tomorrow NN
#
# in IN
#
# Hawaii NNP
#
# ? .
#
# @DrHubaEvaluator USR
#
# Not RB
#
# long RB
#
# ago RB
#
# I PRP
#
# responded VBD
#
# to TO
#
# a DT
#
# angry JJ
#
# cardiologist NN
#
# whom WP
#
# I PRP
#
# have VBP
#
# known VBN
#
# yrs NNS
#
# . .
#
# when WRB
#
# he PRP
#
# spit VBP
#
# venom NN
#
# to TO
#
# the DT
#
# newspaper NN
#
# but CC
#
# I PRP
# did VBD
#
# it PRP
#
# + SYM
#
# @Strigy USR
#
# got VBD
#
# mine NN
#
# in IN
#
# bbt NNP
#
# aintree NNP
#
# today NN
#
# . .
#
# Played VBD
#
# table NN
#
# tennis NN
#
# on IN
#
# it PRP
#
# in IN
#
# store NN
#
# ! .
#
# V RB
#
# impressed VBD
#
# . .
#
# Did VB
#
# you PRP
#
# get VB
#
# analogue JJ
#
# controller NN
#
# 2 RB
#
# ? .
#
# USM NNP
#
# get VB
#
# ready RB
#
# yours PRP$
#
# truly RB
#
# tonight NN
#
# at IN
#
# frat NN
#
# house NN
#
# Hattiesburg NNP
#
# on IN
#
# the DT
#
# 1s CD
#
# n CC
#
# 2s CD
#
# !! .
#
# Today NN
#
# 's POS
#
# cheer NN
#
# went VBD
#
# from IN
#
# awful JJ
#
# to TO
#
# awesome JJ
#
# from IN
#
# the DT
#
# moment NN
#
# I PRP
#
# realized VBD
#
# I PRP
#
# did VBD
#
# not RB
#
# have VB
#
# class NN
#
# today NN
#
# . .
#
# @jonronson USR
#
# But CC
#
# a DT
#
# mess NN
#
# on IN
#
# one CD
#
# day NN
#
# may MD
#
# not RB
#
# a DT
#
# mess NN
#
# eternally RB
#
# be VB
#
# . .
#
# Driving VBG
#
# , ,
#
# driving VBG
#
# , ,
#
# driving VBG
#
# away RB
#
# to TO
#
# Phil NNP
#
# . .
#
# Tasty JJ
#
# dinner NN
#
# tonight NN
#
# with IN
#
# the DT
#
# Society NNP
#
# of IN
#
# Mining NNP
#
# and CC
#
# Metallurgy NNP
#
# Engineers NNPS
#
# . .
#
# Have VBP
#
# a DT
#
# practice NN
#
# session NN
#
# @Cromwell USR
#
# Field NN
#
# today NN
#
# at IN
#
# 6pm CD
#
# . .
#
# Hope VBP
#
# i PRP
#
# shine VBP
#
# well RB
#
# and CC
#
# start VB
#
# the DT
#
# next JJ
#
# game NN
#
# . .
#
# :) UH
#
# Pxleyes NNP
#
# Top NNP
#
# 50 CD
#
# Photography NNP
#
# Contest NNP
#
# Pictures NNS
#
# of IN
#
# August NNP
#
# 2010 CD
#
# ... :
#
# http://bit.ly/bgCyZ0 URL
#
# #photography HT
#
# Costa JJ
#
# Rican JJ
#
# group NN
#
# CocoFunka NNP
#
# power VBP
#
# this DT
#
# week NN
#
# 's POS
#
# Indiesent NNP
#
# Exposure NNP
#
# http://ht.ly/2G4nS URL
#
# by IN
#
# @fuseboxradio USR
#
# on IN
#
# @planetill USR
#
# RT RT
#
# @Quotealicious USR
#
# : :
#
# Today NN
#
# , ,
#
# I PRP
#
# saw VBD
#
# a DT
#
# guy NN
#
# driving VBG
#
# a DT
#
# Pepsi NNP
#
# truck NN
#
# , ,
#
# drinking VBG
#
# a DT
#
# Coke NNP
#
# . .
#
# MLIA UH
#
# #Quotealicious HT
#
# After IN
#
# I PRP
#
# pet VBP
#
# a DT
#
# kitten NN
#
# on IN
#
# JFK NNP
#
# , ,
#
# the DT
#
# owners NNS
#
# informed VBD
#
# me PRP
#
# it PRP
#
# 's VBZ
#
# ' ''
#
# double-pawed JJ
#
# ' ''
#
# ( (
#
# polydactyl) NN
#
# , ,
#
# which WDT
#
# is VBZ
#
# " ''
#
# a DT
#
# form NN
#
# of IN
#
# retardation NN
#
# in IN
#
# the DT
#
# animal NN
#
# kingdom NN
#
# " ''
#
# I PRP
#
# 'm VBP
#
# tired JJ
#
# after IN
#
# school NN
#
# today NN
#
# ! .
#
# About NNP
#
# online NN
#
# dietician NN
#
# : :
#
# A DT
#
# thinner JJR
#
# stool NN
#
# than IN
#
# usual JJ
#
# can MD
#
# be VB
#
# identified VBN
#
# and CC
#
# removed VBN
#
# before IN
#
# they PRP
#
# get VBP
#
# are VBP
#
# 2 CD
#
# weeks NNS
#
# ago IN
#
# J NNP
#
# ... :
#
# http://bit.ly/cYGBdz URL
#
# Greek NNP
#
# Festival NNP
#
# at IN
#
# St NNP
#
# Johns NNP
#
# before IN
#
# ASPEN NNP
#
# The NNP
#
# Town NNP
#
# might MD
#
# be VB
#
# one CD
#
# of IN
#
# the DT
#
# best JJS
#
# movies NNS
#
# I PRP
#
# have VBP
#
# seen VBN
#
# all DT
#
# year NN
#
# . .
#
# So RB
#
# , ,
#
# so RB
#
# good JJ
#
# . .
#
# And CC
#
# do VB
#
# n't RB
#
# worry VB
#
# Ben NNP
#
# , ,
#
# we PRP
#
# already RB
#
# forgave VBP
#
# you PRP
#
# for IN
#
# Gigli NNP
#
# . .
#
# Really RB
#
# . .
#
# @Jsmoothhh USR
#
# it PRP
#
# 's VBZ
#
# not RB
#
# supposed VBN
#
# to TO
#
# rain VB
#
# till IN
#
# Sunday NNP
#
# night NN
#
# . .
#
# So RB
#
# far RB
#
# this DT
#
# day NN
#
# xxx JJ
#
# ; :
#
# t RB
#
# gone VBN
#
# to TO
#
# well RB
#
# , ,
#
# hopefully RB
#
# my PRP$
#
# night NN
#
# will MD
#
# be VB
#
# better JJR
#
# ! .
#
# Going VBG
#
# to TO
#
# the DT
#
# country NN
#
# fair NN
#
# today NN
#
# :) UH
#
# Lindsay NNP
#
# Lohan NNP
#
# allegedly RB
#
# failed VBD
#
# her PRP$
#
# drug NN
#
# test NN
#
# . .
#
# So RB
#
# not RB
#
# fetch JJ
#
# . .
#
# Quick RB
#
# , ,
#
# let VB
#
# 's POS
#
# all DT
#
# put VBP
#
# on IN
#
# our PRP$
#
# shocked JJ
#
# faces NNS
#
# that IN
#
# 23 CD
#
# days NNS
#
# of IN
#
# rehab NN
#
# did VBD
#
# n't RB
#
# work VB
#
# ! .
#
# @SweetBee_90 USR
#
# what WP
#
# 's VBZ
#
# the DT
#
# look NN
#
# for IN
#
# tonight NN
#
# ? .
#
# I PRP
#
# remember VBP
#
# when WRB
#
# you PRP
#
# all DT
#
# were VBD
#
# thiiis DT
#
# big JJ
#
# , ,
#
# you PRP
#
# know VBP
#
# ? .
#
# going VBG
#
# now RB
#
# guiseeeee NNS
#
# ... :
#
# if IN
#
# i PRP
#
# dont VBP
#
# see VB
#
# you PRP
#
# through IN
#
# the DT
#
# week NN
#
# ill MD
#
# see VB
#
# you PRP
#
# through IN
#
# the DT
#
# window NN
#
# :) UH
#
# :) UH
#
# Beautiful JJ
#
# day NN
#
# in IN
#
# Chicago NNP
#
# ! .
#
# Nice JJ
#
# to TO
#
# get VB
#
# away RB
#
# from IN
#
# the DT
#
# Florida NNP
#
# heat NN
#
# . .
#
# But CC
#
# what WP
#
# happens VBZ
#
# when WRB
#
# karam NNP
#
# turns VBZ
#
# right RB
#
# around RP
#
# and CC
#
# bites VBZ
#
# you PRP
#
# ? .
#
# And CC
#
# everything NN
#
# you PRP
#
# stand VBP
#
# for IN
#
# turns VBZ
#
# on IN
#
# you PRP
#
# despite IN
#
# you PRP
#
# ? .
#
# @alealshinn USR
#
# @BambingBling USR
#
# ~~~ :
#
# @sunchips USR
#
# this DT
#
# is VBZ
#
# the DT
#
# second JJ
#
# time NN
#
# they PRP
#
# have VBP
#
# messed VBD
#
# up RP
#
# .... :
#
# about IN
#
# to TO
#
# give VB
#
# up RP
#
# on IN
#
# them PRP
#
# #blackholidays HT
#
# " ''
#
# National JJ
#
# forget VB
#
# the DT
#
# he PRP
#
# say VBP
#
# she PRP
#
# say VBP
#
# ... :
#
# what WP
#
# do VBP
#
# God NNP
#
# say VB
#
# day NN
#
# " ''
#
# JV NN
#
# soccer NN
#
# leads VBZ
#
# 4-1 JJ
#
# after IN
#
# Benitez NNP
#
# scores VBZ
#
# again RB
#
# , ,
#
# less JJR
#
# than IN
#
# 7 CD
#
# mins NNS
#
# to TO
#
# play VB
#
# Aggressive JJ
#
# Kids NNS
#
# With IN
#
# ADHD NNP
#
# May MD
#
# Not RB
#
# Need VB
#
# Antipsychotic JJ
#
# Meds NNS
#
# http://t.co/JfGm0uH URL
#
# @princessmariam9 USR
#
# i PRP
#
# know VBP
#
# .. :
#
# i PRP
#
# need VBP
#
# to TO
#
# stop VB
#
# before IN
#
# my PRP$
#
# room NN
#
# is VBZ
#
# gonna VBG
#
# get VB
#
# filled VBN
#
# with IN
#
# water NN
#
# . .
#
# @BornThisWayBaby USR
#
# thankk VB
#
# yhuu PRP
#
# #monsterlove HT
#
# u PRP
#
# just RB
#
# made VBD
#
# my PRP$
#
# day NN
#
# :D UH
#
# @mekamoe927 USR
#
# I PRP
#
# 've VBP
#
# had VBN
#
# one CD
#
# before RB
#
# , ,
#
# but CC
#
# it PRP
#
# was VBD
#
# a DT
#
# short JJ
#
# experience NN
#
# ( (
#
# double JJ
#
# entendre NN
#
# intended) VBD
#
# . .
#
# Why WRB
#
# hate VBP
#
# on IN
#
# somebody NN
#
# for IN
#
# doing VBG
#
# well RB
#
# when WRB
#
# you PRP
#
# can MD
#
# simply RB
#
# say VB
#
# great JJ
#
# job NN
#
# and CC
#
# move VB
#
# on IN
#
# .. .
#
# [Haters NNS
#
# u PRP
#
# can MD
#
# kill VB
#
# yourself PRP
#
# ] :
#
# cuz IN
#
# ur PRP
#
# losers NNS
#
# If IN
#
# you PRP
#
# are VBP
#
# staying VBG
#
# in IN
#
# Gainesville NNP
#
# , ,
#
# come VB
#
# check VB
#
# out RP
#
# Costa NNP
#
# Lounge NNP
#
# TONIGHT NN
#
# ! .
#
# Say VB
#
# you PRP
#
# are VBP
#
# with IN
#
# salsa NNP
#
# caliente NNP
#
# and CC
#
# get VB
#
# in IN
#
# ... :
#
# http://fb.me/FZVzm8H9 URL
#
# @godsgirl8494 USR
#
# can MD
#
# u PRP
#
# please VPP
#
# follow VB
#
# me PRP
#
# ? .
#
# you PRP
#
# will MD
#
# make VB
#
# my PRP$
#
# day NN
#
# &lt; UH
#
# 3 UH
#
# 8 CD
#
# Ugh UH
#
# I PRP
#
# DO VBP
#
# N'T RB
#
# HAVE VB
#
# MY PRP$
#
# EARPHONES NNS
#
# I PRP
#
# GUESS VBP
#
# I PRP
#
# WO MD
#
# N'T RB
#
# B VB
#
# TALKING VBG
#
# AND CC
#
# DRIVING VBG
#
# TODAY NN
#
# LOL UH
#
# .... :
#
# Excuses NNS
#
# Excuses NNS
#
# Excuses NNS
#
# SMH UH
#
# There EX
#
# was VBD
#
# just RB
#
# a DT
#
# fire NN
#
# at IN
#
# work NN
#
# . .
#
# Today NN
#
# is VBZ
#
# looking VBG
#
# up RP
#
# . .
#
# Haha UH
#
# I PRP
#
# seen VBN
#
# a DT
#
# ped JJ
#
# egg NN
#
# called VBD
#
# a DT
#
# foot NN
#
# cheese NN
#
# grater NN
#
# today NN
#
# . .
#
# I PRP
#
# found VBD
#
# it PRP
#
# proper JJ
#
# hilarious JJ
#
# xD UH
#
# For IN
#
# code NN
#
# I PRP
#
# 've VBP
#
# written VBN
#
# since IN
#
# Sept NNP
#
# ' ''
#
# 09 CD
#
# , ,
#
# the DT
#
# delay NN
#
# between IN
#
# commit VBZ
#
# to TO
#
# SCM NNP
#
# and CC
#
# running VBG
#
# on IN
#
# customer NN
#
# hardware NN
#
# has VBZ
#
# been VBN
#
# about IN
#
# 10 CD
#
# days NNS
#
# . .
#
# Good JJ
#
# start NN
#
# for IN
#
# sharks NNP
#
# tonight NN
#
# can MD
#
# only RB
#
# get VB
#
# better JJR
#
# . .
#
# Played VBD
#
# with IN
#
# short JJ
#
# bench NN
#
# tonight NN
#
# . .
#
# Thought VBD
#
# Rocks NNP
#
# well RB
#
# in IN
#
# game NN
#
# early RB
#
# though IN
#
# until IN
#
# ' ''
#
# unseen NN
#
# ' ''
#
# @sarahk47 USR
#
# Okay UH
#
# The DT
#
# doc NN
#
# 's VBZ
#
# saying VBG
#
# Keep VB
#
# it PRP
#
# tamped VBN
#
# down RP
#
# a DT
#
# coupla NN
#
# days NNS
#
# then IN
#
# bring VB
#
# her PRP
#
# out IN
#
# early RB
#
# ? .
#
# " ''
#
# before IN
#
# we PRP
#
# start VBP
#
# , ,
#
# how WRB
#
# old JJ
#
# are VBP
#
# you PRP
#
# ? .
#
# HER PRP
#
# : :
#
# I PRP
#
# 'm VBP
#
# 15 CD
#
# .. :
#
# old JJ
#
# enough RB
#
# !........ :
#
# #FindTheNearestExit HT
#
# RT RT
#
# @ericjohnsalut USR
#
# " ''
#
# Good UH
#
# Morning UH
#
# ! .
#
# Have VB
#
# a DT
#
# pleasant JJ
#
# and CC
#
# happy JJ
#
# day NN
#
# !" .
#
# http://dlvr.it/5Rh4w URL
#
# VIDEO NN
#
# : :
#
# Showbiz NNP
#
# Tonight NNP
#
# - :
#
# Is VBZ
#
# TV NN
#
# Too RB
#
# Gay JJ
#
# ?: :
#
# http://bit.ly/aAZMD6 URL
#
# when WRB
#
# did VBD
#
# @thecodysimpson USR
#
# last RB
#
# tweet VBZ
#
# ,? .
#
# ;) UH
#
# [ (
#
# GigaOM NNP
#
# ] )
#
# DRM NNP
#
# FAIL VB
#
# : :
#
# Five CD
#
# Broken JJ
#
# Copy NN
#
# Protection NN
#
# Schemes NNS
#
# : :
#
# This DT
#
# week NN
#
# , ,
#
# we PRP
#
# learned VBD
#
# that IN
#
# the DT
#
# HDCP NNP
#
# copy NN
#
# protection NN
#
# scheme NN
#
# ... :
#
# http://bit.ly/blWf0e URL
#
# Was VBD
#
# hard JJ
#
# work NN
#
# going VBG
#
# to TO
#
# the DT
#
# gym NN
#
# on IN
#
# my PRP$
#
# own JJ
#
# tonight NN
#
# but CC
#
# managed VBD
#
# a DT
#
# 30 CD
#
# min NN
#
# run NN
#
# and CC
#
# plenty RB
#
# of IN
#
# weights NNS
#
# . .
#
# Catching VBG
#
# up RP
#
# on IN
#
# ufc NNP
#
# now RB
#
# From IN
#
# Green NNP
#
# Newsfeed NNP
#
# : :
#
# AHFA NNP
#
# extends VBZ
#
# deadline NN
#
# for IN
#
# Sage NNP
#
# Award NNP
#
# to TO
#
# Nov NNP
#
# . .
#
# 5 CD
#
# http://tinyurl.com/24agj38 URL
#
# Thrilled VBN
#
# about IN
#
# this DT
#
# @HPC//RT@DeLynnRizzo USR
#
# : :
#
# girls NNS
#
# , ,
#
# register4 VB
#
# #livethedream HT
#
# @joycemeyer USR
#
# , ,
#
# J NNP
#
# John NNP
#
# , ,
#
# @kerriweems USR
#
# oct NNP
#
# 7-9 CD
#
# . .
#
# livethedreamconference URL
#
# . URL
#
# com URL
#
# 4Dbling NNP
#
# 's POS
#
# place NN
#
# til IN
#
# monday NNP
#
# , ,
#
# party NN
#
# party NN
#
# party NN
#
# . .
#
# &lt; UH
#
# 3 UH
#
# @FeeninforPretty USR
#
# making VBG
#
# something NN
#
# to TO
#
# eat VB
#
# , ,
#
# aint VBP
#
# ate VB
#
# all DT
#
# day NN
#
# omg UH
#
# simone NNP
#
# is VBZ
#
# coming VBG
#
# over IN
#
# then IN
#
# 2morrow NN
#
# we PRP
#
# foin VBG
#
# 2 TO
#
# da DT
#
# fall NN
#
# festival NN
#
# cant MD
#
# wait VB
#
# 4 IN
#
# GAC NNP
#
# 2night NN
#
# ! .
#
# an CC
#
# Justin NNP
#
# Bieber NNP
#
# concert NN
#
# in IN
#
# Dec NNP
#
# .!!!!!!! .
#
# &lt; UH
#
# 3 UH
#
# 27 CD
#
# followers NNS
#
# ! .
#
# 30 CD
#
# followers NNS
#
# is VBZ
#
# my PRP$
#
# goal NN
#
# for IN
#
# today NN
#
# ! .
#
# good JJ
#
# friday NNP
#
# whatchu PRP
#
# got VB
#
# for IN
#
# me PRP
#
# @kanyewest USR
#
# I PRP
#
# see VBP
#
# her PRP
#
# tomorrow NN
#
# : UH
#
# 3 UH
#
# so UH
#
# yeah~ UH
#
# ca MD
#
# n't RB
#
# wait VB
#
# Friday NNP
#
# Night NNP
#
# Eats NNPS
#
# http://twitpic.com/2pdvtr URL
#
# RT RT
#
# @kanyewest USR
#
# : :
#
# You PRP
#
# basically RB
#
# can MD
#
# say VB
#
# anything NN
#
# to TO
#
# someone NN
#
# on IN
#
# an DT
#
# email NN
#
# or CC
#
# text NN
#
# as IN
#
# long RB
#
# as IN
#
# you PRP
#
# put VBP
#
# LOL NN
#
# at IN
#
# the DT
#
# end NN
#
# @Bills_Ears USR
#
# WELL UH
#
# SORRRY JJ
#
# !! .
#
# I PRP
#
# did VBD
#
# n't RB
#
# know VB
#
# you PRP
#
# YEARS NNS
#
# AGO RB
#
# ! .
#
# Salty UH
#
# i PRP
#
# broke VBD
#
# one CD
#
# of IN
#
# my PRP$
#
# favorite JJ
#
# Betsey NNP
#
# Johnson NNP
#
# necklaces NNS
#
# today NN
#
# !! .
#
# #NFL HT
#
# Week NN
#
# 2 CD
#
# picks NNS
#
# blog NN
#
# is VBZ
#
# up RB
#
# on IN
#
# @The_Score USR
#
# website NN
#
# ... :
#
# http://blogs.thescore.com/nfl/2010/09/17/pizzolaw2/ URL
#
# cant MD
#
# wait VB
#
# to TO
#
# see VB
#
# my PRP$
#
# beautiful JJ
#
# neice NN
#
# nx JJ
#
# week NN
#
# , ,
#
# gonna VBG
#
# spoil VB
#
# her PRP
#
# rotton JJ
#
# @winashbrown USR
#
# If IN
#
# that DT
#
# auto NN
#
# URL NN
#
# shortening NN
#
# could MD
#
# work VB
#
# I PRP
#
# might MD
#
# stick VB
#
# with IN
#
# SD2 NNP
#
# for IN
#
# a DT
#
# while NN
#
# - :
#
# that IN
#
# saves VBZ
#
# me PRP
#
# 3 CD
#
# or CC
#
# 4 CD
#
# steps NNS
#
# when WRB
#
# I PRP
#
# am VBP
#
# tweeting VBG
#
# links NNS
#
# RT RT
#
# @therbertson USR
#
# : :
#
# Just RB
#
# saw VBD
#
# the DT
#
# worst JJS
#
# movie NN
#
# in IN
#
# years NNS
#
# ... :
#
# Piranha NNP
#
# 3D NNP
#
# just RB
#
# exceeded VBN
#
# the DT
#
# limits NNS
#
# of IN
#
# crappyness NN
#
# . .
#
# | :
#
# Glad JJ
#
# you PRP
#
# enjoyed VBD
#
# it PRP
#
# . .
#
# RT RT
#
# @midgetmegs USR
#
# : :
#
# hate VBP
#
# people NNS
#
# who WP
#
# write VBP
#
# drunk JJ
#
# status'. NN
#
# must MD
#
# be VB
#
# having VBG
#
# a DT
#
# great JJ
#
# time NN
#
# if IN
#
# your PRP
#
# sat NNP
#
# writing VBG
#
# it PRP
#
# on IN
#
# facebook NNP
#
# ..... :
#
# Kahlua NNP
#
# & CC
#
# Coffee NNP
#
# over IN
#
# looking JJ
#
# the DT
#
# lake NN
#
# is VBZ
#
# just RB
#
# what WP
#
# the DT
#
# doctor NN
#
# ordered VBD
#
# .... :
#
# hope VBP
#
# everyone NN
#
# has VBZ
#
# a DT
#
# great JJ
#
# Friday NNP
#
# night NN
#
# ! .
#
# Football NN
#
# game NN
#
# tonight NN
#
# with IN
#
# mariaelena NNP
#
# , ,
#
# sarah NNP
#
# , ,
#
# and CC
#
# brittany NNP
#
# ! .
#
# Mood NN
#
# : :
#
# excited JJ
#
# !! .
#
# GOO VB
#
# WB NNP
#
# WILDCATS NNP
#
# ! .
#
# Gotta VBP
#
# love VB
#
# the DT
#
# bumper NN
#
# stickers NNS
#
# of IN
#
# Fayette NNP
#
# County NNP
#
# : :
#
# " ''
#
# Ever RB
#
# wonder VBP
#
# if IN
#
# there EX
#
# is VBZ
#
# life NN
#
# after IN
#
# death NN
#
# ? .
#
# Touch VB
#
# my PRP$
#
# truck NN
#
# and CC
#
# 'll MD
#
# find VB
#
# out RP
#
# ." :
#
# @mfeige USR
#
# it PRP
#
# 's VBZ
#
# on IN
#
# a DT
#
# Saturday NNP
#
# though RB
#
# . .
#
# So RB
#
# that DT
#
# 's VBZ
#
# a DT
#
# thing NN
#
# . .
#
# 3 CD
#
# tests NNS
#
# and CC
#
# an DT
#
# essay NN
#
# today NN
#
# . .
#
# &gt; UH
#
# __ UH
#
# &gt; UH
#
# also RB
#
# i PRP
#
# lost VBD
#
# my PRP$
#
# backpackkk NN
#
# c UH
#
# : UH
#
# but CC
#
# then RB
#
# i PRP
#
# found VBD
#
# it PRP
#
# . .
#
# RT RT
#
# @DaymiCarolina USR
#
# : :
#
# Yayaayayay UH
#
# kings NNP
#
# of IN
#
# leon NNP
#
# tonight NN
#
# !!! .
#
# No UH
#
# I PRP
#
# 'm VBP
#
# not RB
#
# saying VBG
#
# I PRP
#
# 'm VBP
#
# sorry JJ
#
# One CD
#
# day NN
#
# , ,
#
# maybe RB
#
# 'll MD
#
# meet VB
#
# again RB
#
# No RB
#
# No RB
#
# No RB
#
# No RB
#
# ( (
#
# 8 CD
#
# ) )
#
# Companies NNS
#
# fixing VBG
#
# a DT
#
# problem NN
#
# that WDT
#
# 's VBZ
#
# wholly RB
#
# their PRP$
#
# fault NN
#
# and CC
#
# calling VBG
#
# it PRP
#
# a DT
#
# " ''
#
# one-time JJ
#
# courtesy NN
#
# " ''
#
# is VBZ
#
# insult NN
#
# to TO
#
# injury NN
#
# . .
#
# They PRP
#
# 're VBP
#
# clearly RB
#
# not RB
#
# sorry JJ
#
# ! .
#
# @_mistercory USR
#
# *Smiles VB
#
# up IN
#
# at IN
#
# him* PRP
#
# Can MD
#
# we PRP
#
# just RB
#
# ... :
#
# sit VB
#
# together RB
#
# for IN
#
# a DT
#
# while NN
#
# before IN
#
# round NN
#
# two CD
#
# ? .
#
# I PRP
#
# am VBP
#
# living VBG
#
# my PRP$
#
# dream NN
#
# , ,
#
# winning VBG
#
# at IN
#
# life NN
#
# and CC
#
# being VBG
#
# respected VBN
#
# for IN
#
# every DT
#
# thing NN
#
# I PRP
#
# do VBP
#
# . .
#
# And CC
#
# its PRP
#
# about IN
#
# fucking RB
#
# time NN
#
# . .
#
# #dontsettle HT
#
# #EVER HT
#
# the DT
#
# last JJ
#
# group NN
#
# dalam VB
#
# lab NN
#
# , ,
#
# for IN
#
# the DT
#
# first JJ
#
# time NN
#
# @pjames USR
#
# Add VB
#
# a DT
#
# little JJ
#
# Belanger NNP
#
# , ,
#
# and CC
#
# you PRP
#
# 've VBP
#
# got VBN
#
# it PRP
#
# ! .
#
# Of IN
#
# course NN
#
# ... :
#
# after IN
#
# his PRP$
#
# household NN
#
# items NNS
#
# arrive VBP
#
# from IN
#
# D NNP
#
# . .
#
# C NNP
#
# . .
#
# RT RT
#
# @OMGwhatateen USR
#
# : :
#
# RT RT
#
# if IN
#
# you PRP
#
# are VBP
#
# happy JJ
#
# it PRP
#
# 's VBZ
#
# friday NNP
#
# . .
#
# #OMGwhatateen HT
#
# Halo NNP
#
# Reach NNP
#
# was VBD
#
# a DT
#
# bit JJ
#
# crap NN
#
# tonight NN
#
# @Miss_deadpool USR
#
# May NNP
#
# 's POS
#
# costume NN
#
# is VBZ
#
# the DT
#
# giant JJ
#
# spider NN
#
# on IN
#
# her PRP$
#
# upper NN
#
# body NN
#
# . .
#
# I PRP
#
# 'm VBP
#
# JJ VBN
#
# . .
#
# Working VBG
#
# at IN
#
# my PRP$
#
# old JJ
#
# office NN
#
# tomorrow NN
#
# to TO
#
# catch VB
#
# the DT
#
# bookkeeping NN
#
# up RP
#
# . .
#
# Money NN
#
# to TO
#
# do VB
#
# easy JJ
#
# stuff NN
#
# when WRB
#
# I PRP
#
# would MD
#
# just RB
#
# be VB
#
# sitting VBG
#
# around IN
#
# anyway NN
#
# ? .
#
# Yes UH
#
# plz UH
#
# . .
#
# QUAKE NN
#
# : :
#
# Mag NN
#
# 4.5 CD
#
# , ,
#
# Saturday NNP
#
# , ,
#
# September NNP
#
# 18 CD
#
# 2010 CD
#
# at IN
#
# 10:03 CD
#
# am NN
#
# ( (
#
# NZST) NNP
#
# , ,
#
# 20 CD
#
# km NN
#
# south-west JJ
#
# of IN
#
# Christchurch NNP
#
# . .
#
# http://tinyurl.com/265n4mx URL
#
# #eqnz HT
#
# RT RT
#
# @Eeenie_Meenie USR
#
# : :
#
# RT RT
#
# if IN
#
# you PRP
#
# are VBP
#
# happy JJ
#
# that IN
#
# today NN
#
# is VBZ
#
# FRIDAY NNP
#
# ! .
#
# :) UH
#
# Wanna VBP
#
# see VB
#
# ya PRP
#
# bro UH
#
# , ,
#
# I PRP
#
# miss VBP
#
# u PRP
#
# U PRP
#
# scared VBD
#
# me PRP
#
# to TO
#
# hell NN
#
# yesterday NN
#
# , ,
#
# cant MD
#
# live VB
#
# without IN
#
# u PRP
#
# U PRP
#
# 're VBP
#
# more JJR
#
# than IN
#
# a DT
#
# bro NN
#
# u PRP
#
# 're VBP
#
# Like IN
#
# my PRP$
#
# twin NN
#
# Need VBP
#
# u PRP
#
# , ,
#
# come VB
#
# home NN
#
# Luv VBP
#
# u PRP
#
# &lt; UH
#
# 3 UH
#
# TWEET UH
#
# ! :
#
# @stjosephs USR
#
# Empls NNS
#
# of IN
#
# the DT
#
# Month NN
#
# : :
#
# Deborah NNP
#
# L NNP
#
# #Speech HT
#
# #Pathologist-Childrens HT
#
# Rehab NN
#
# and CC
#
# Patricia NNP
#
# M NNP
#
# #Referral/#Auth HT
#
# #Spec-#Womens HT
#
# #Care HT
# ! .
#
# RT RT
#
# @BuffSabresGrl63 USR
#
# : :
#
# RT RT
#
# @LindyRuffsTie USR
#
# : :
#
# RT RT
#
# @FakeDarcy USR
#
# : :
#
# No UH
#
# Derek NNP
#
# , ,
#
# when WRB
#
# guys NNS
#
# get VBP
#
# hurt VBN
#
# , ,
#
# " ''
#
# kissing VBG
#
# the DT
#
# boo-boo NN
#
# " ''
#
# will MD
#
# not RB
#
# make VB
#
# it PRP
#
# better JJR
#
# . .
#
# #sab HT
#
# ... :
#
# RT RT
#
# @TRAEABN USR
#
# Headed VBN
#
# to TO
#
# Shreveport NNP
#
# then IN
#
# Lake NNP
#
# Charles NNP
#
# -might MD
#
# as IN
#
# well RB
#
# shoot VB
#
# through IN
#
# dat DT
#
# #BMT HT
#
# after IN
#
# the DT
#
# slab NN
#
# show NN
#
# in IN
#
# Lake NNP
#
# Charles NNP
#
# .. .
#
# RT RT
#
# @WeSpazForJB USR
#
# : :
#
# http://twitpic.com/2nn4ee URL
#
# &lt; SYM
#
# ---- SYM
#
# still RB
#
# the DT
#
# funniest JJS
#
# photo NN
#
# . .
#
# of IN
#
# all DT
#
# time NN
#
# . .
#
# ALL DT
#
# TIME NN
#
# . .
#
# I PRP
#
# have VBP
#
# eaten VBN
#
# a DT
#
# large JJ
#
# quantity NN
#
# of IN
#
# oranges NNS
#
# this DT
#
# week NN
#
# ... :
#
# RT RT
#
# @NickSilly USR
#
# : :
#
# Fun JJ
#
# ! .
#
# RT RT
#
# @JackFMDFW USR
#
# : :
#
# Put VB
#
# on IN
#
# your PRP$
#
# Boogie NN
#
# Shoes NNS
#
# and CC
#
# Get VB
#
# Down RP
#
# Tonight NN
#
# with IN
#
# KC NNP
#
# and CC
#
# The NNP
#
# Sunshine NNP
#
# Band NNP
#
# . .
#
# #Dallas HT
#
# #concerts HT
#
# http URL
#
# :/ :
#
# ... :
#
# Someone NN
#
# just RB
#
# started VBD
#
# following VBG
#
# me PRP
#
# today NN
#
# so IN
#
# I PRP
#
# better MD
#
# post VB
#
# something NN
#
# . .
#
# There UH
#
# . .
#
# i PRP
#
# want VBP
#
# a DT
#
# bath NN
#
# but CC
#
# do VBP
#
# n't RB
#
# have VB
#
# a DT
#
# bath NN
#
# , ,
#
# shut VB
#
# up RP
#
# , ,
#
# sam NNP
#
# 's VBZ
#
# coming VBG
#
# tomorrow NN
#
# and CC
#
# steve NNP
#
# and CC
#
# tanya NNP
#
# will MD
#
# be VB
#
# round RB
#
# at IN
#
# 10am CD
#
# so IN
#
# go VB
#
# away RB
#
# you PRP
#
# mean JJ
#
# people NNS
#
# What WP
#
# Do VBP
#
# S.F. NNP
#
# Rabbis NNS
#
# Eat VBZ
#
# Before IN
#
# and CC
#
# After IN
#
# Yom NNP
#
# Kippur NNP
#
# ? .
#
# We PRP
#
# Asked VBD
#
# Five CD
#
# to TO
#
# Enlighten VB
#
# Us PRP
#
# ! .
#
# via IN
#
# @SFoodie USR
#
# http://bit.ly/aQrFUz URL
#
# Half PDT
#
# baked JJ
#
# , ,
#
# next JJ
#
# how WRB
#
# high JJ
#
# , ,
#
# grandma NN
#
# boys NNS
#
# , ,
#
# puff VB
#
# puff VB
#
# pass VB
#
# , ,
#
# and CC
#
# 4 CD
#
# hours NNS
#
# of IN
#
# friday NNP
#
# . .
#
# &lt; SYM
#
# DEAD NNP
#
# GREEN NNP
#
# HARTS NNP
#
# &gt; SYM
#
# @mcflysandra USR
#
# haha UH
#
# yes UH
#
# :) UH
#
# have VBP
#
# to TO
#
# go VB
#
# speak VB
#
# tomorrow NN
#
# :) UH
#
# good JJ
#
# night NN
#
# xxx UH
#
# RT RT
#
# @GreatestQuotes USR
#
# : :
#
# " ''
#
# When WRB
#
# everything NN
#
# seems VBZ
#
# to TO
#
# be VB
#
# going VBG
#
# against IN
#
# you PRP
#
# , ,
#
# remember VB
#
# that IN
#
# the DT
#
# airplane NN
#
# takes VBZ
#
# off RP
#
# against IN
#
# the DT
#
# wind NN
#
# , ,
#
# not RB
#
# with IN
#
# it PRP
#
# ." :
#
# ... :
#
# @2kjdream USR
#
# Good JJ
#
# morning NN
#
# ! .
#
# Have VB
#
# a DT
#
# Good JJ
#
# day NN
#
# :) UH
#
# from IN
#
# JPN NNP
#
# . .
#
# DITR NNP
#
# REI NNP
#
# Update NN
#
# : :
#
# California NNP
#
# Home NN
#
# Sales NNS
#
# Decline VBZ
#
# Year-Over-Year JJ
#
# : :
#
# By IN
#
# Michael NNP
#
# Kraus NNP
#
# on IN
#
# September NNP
#
# 17 CD
#
# ... :
#
# http://bit.ly/96Zavf URL
#
# #realestate HT
#
# #invest HT
#
# Good UH
#
# golly UH
#
# . .
#
# Who WP
#
# left VBD
#
# the DT
#
# candy NN
#
# in IN
#
# the DT
#
# lunchroom NN
#
# . .
#
# May MD
#
# set VBD
#
# a DT
#
# world NN
#
# record NN
#
# for IN
#
# the DT
#
# most JJS
#
# Sour NNP
#
# Patch NNP
#
# kids NNPS
#
# eaten VBN
#
# by IN
#
# an DT
#
# individual NN
#
# ! .
#
# Last JJ
#
# stop NN
#
# of IN
#
# the DT
#
# day NN
#
# thank VB
#
# goddddd NNP
#
# (@ :
#
# H-E-B NNP
#
# Plus NNP
#
# ) )
#
# http://4sq.com/7RDhgd URL
#
# Exclusive JJ
#
# : :
#
# Rep NNP
#
# . .
#
# Steve NNP
#
# King NNP
#
# on IN
#
# ObamaCare NNP
#
# , ,
#
# Tea NNP
#
# Party NNP
#
# , ,
#
# and CC
#
# Constitution NNP
#
# Day NNP
#
# : :
#
# The DT
#
# inclusion NN
#
# of IN
#
# the DT
#
# Tenth NNP
#
# Amendment NNP
#
# in IN
#
# ... :
#
# http://bit.ly/cYITA8 URL
#
# Long JJ
#
# 18k CD
#
# run NN
#
# done VBN
#
# and CC
#
# in IN
#
# the DT
#
# books NNS
#
# ! .
#
# Beauty JJ
#
# day NN
#
# . .
#
# Til IN
#
# now RB
#
# , ,
#
# at IN
#
# dentist NN
#
# , ,
#
# and CC
#
# lady NN
#
# next JJ
#
# to TO
#
# me PRP
#
# spilling VBG
#
# over IN
#
# to TO
#
# my PRP$
#
# chair NN
#
# .. :
#
# Just RB
#
# belched VBD
#
# . .
#
# Loudly RB
#
# . .
#
# +1 CD
#
# You PRP
#
# gotta VBP
#
# let VB
#
# em PRP
#
# lick VB
#
# it PRP
#
# before IN
#
# they PRP
#
# stick VBP
#
# it PRP
#
# @Hollly_ USR
#
# 16 CD
#
# b VB
#
# 17 CD
#
# in IN
#
# feb NNP
#
# There EX
#
# 's VBZ
#
# a DT
#
# lot NN
#
# of IN
#
# people NNS
#
# showing VBG
#
# off RP
#
# their PRP$
#
# iPhones NNS
#
# on IN
#
# facebook NNP
#
# today NN
#
# , ,
#
# so RB
#
# & CC
#
# so RB
#
# is VBZ
#
# at IN
#
# such JJ
#
# a DT
#
# place NN
#
# , ,
#
# it PRP
#
# 's VBZ
#
# really RB
#
# not RB
#
# that DT
#
# interesting JJ
#
# ;o UH
#
# ) )
#
# RT RT
#
# @zahrock12 USR
#
# : :
#
# Fuck UH
#
# yeah UH
#
# its PRP
#
# FRIDAY NNP
#
# !! .
#
# #Astros HT
#
# lineup NN
#
# for IN
#
# tonight NN
#
# . .
#
# Keppinger NNP
#
# sits VBZ
#
# , ,
#
# Downs NNP
#
# plays VBZ
#
# 2B NN
#
# , ,
#
# CJ NNP
#
# bats VBZ
#
# 5th JJ
#
# . .
#
# @alysonfooter USR
#
# http://bit.ly/bHvgCS URL
#
# HA UH
#
# ! :
#
# RT RT
#
# @ew32766 USR
#
# I PRP
#
# love VBP
#
# it PRP
#
# when WRB
#
# my PRP$
#
# mom NN
#
# posts VBZ
#
# status NN
#
# updates NNS
#
# on IN
#
# FB NNP
#
# , ,
#
# they PRP
#
# are VBP
#
# usually RB
#
# personal JJ
#
# messages NNS
#
# she PRP
#
# meant VBD
#
# 2write VB
#
# on IN
#
# someone NN
#
# 's POS
#
# wall NN
#
# . .
#
# ;) UH
#
# #Random HT
#
# But CC
#
# Why WRB
#
# Do VBP
#
# Woman NNS
#
# Say VBZ
#
# The PRP
#
# Want VBP
#
# A DT
#
# Big JJ
#
# D@ck NN
#
# & CC
#
# When WRB
#
# They PRP
#
# Get VBP
#
# It PRP
#
# They PRP
#
# Favorite JJ
#
# Line NN
#
# Is VBZ
#
# " ''
#
# where WRB
#
# is VBZ
#
# that IN
#
# suppose VBP
#
# to TO
#
# go VB
#
# " ''
#
# Knowing VBG
#
# that IN
#
# I PRP
#
# have VBP
#
# people NNS
#
# who WP
#
# love VBP
#
# me PRP
#
# and CC
#
# I PRP
#
# love VBP
#
# them PRP
#
# back RB
#
# makes VBZ
#
# my PRP$
#
# day NN
#
# She PRP
#
# should MD
#
# nom VB
#
# me PRP
#
# when WRB
#
# she PRP
#
# gets VBZ
#
# back RB
#
# ! .
#
# If IN
#
# she PRP
#
# 's VBZ
#
# not RB
#
# tired JJ
#
# that IN
#
# is VBZ
#
# . .
#
# @ashhleybrookee USR
#
# it PRP
#
# may MD
#
# be VB
#
# nasty JJ
#
# but CC
#
# ... :
#
# it PRP
#
# works VBZ
#
# . .
#
# fckn JJ
#
# emily NNP
#
# rodriguez NNP
#
# did VBD
#
# n't RB
#
# bring VB
#
# my PRP$
#
# cookies NNS
#
# today NN
#
# !! .
#
# lil JJ
#
# brat NN
#
# . .
#
# No DT
#
# loss NN
#
# is VBZ
#
# greater JJR
#
# than IN
#
# the DT
#
# loss NN
#
# of IN
#
# a DT
#
# thought NN
#
# process NN
#
# before IN
#
# you PRP
#
# 've VBP
#
# had VBN
#
# the DT
#
# time NN
#
# to TO
#
# write VB
#
# it PRP
#
# down RP
#
# . .
#
# No UH
#
# . .
#
# The DT
#
# Pope NNP
#
# asked VBD
#
# me PRP
#
# to TO
#
# stay VB
#
# after IN
#
# class NN
#
# . .
#
# #moviedialoguewithpopesubstitute HT
#
# Lots NNS
#
# of IN
#
# Merlot NNP
#
# on IN
#
# Thursday NNP
#
# night NN
#
# means VBZ
#
# tired JJ
#
# London NNP
#
# Ladies NNS
#
# are VBP
#
# in IN
#
# bed NN
#
# by IN
#
# 23.19 CD
#
# on IN
#
# the DT
#
# Friday NNP
#
# . .
#
# Listening VBG
#
# to TO
#
# the DT
#
# arts NNS
#
# show NN
#
# on IN
#
# @BBCRadio4 USR
#
# . .
#
# .... :
#
# today NN
#
# is VBZ
#
# better RBR
#
# than IN
#
# yesterday NN
#
# , ,
#
# but CC
#
# I PRP
#
# hope VBP
#
# tomorrow NN
#
# is VBZ
#
# better RBR
#
# than IN
#
# today NN
#
# , ,
#
# because IN
#
# today NN
#
# still RB
#
# somewhat RB
#
# - :
#
# SUCKS VBZ
#
# . .
#
# @Yeweezii USR
#
# Jst RB
#
# lock VB
#
# her PRP
#
# outside IN
#
# 4 IN
#
# d DT
#
# nite NN
#
# . .
#
# It PRP
#
# workz VBZ
#
# al DT
#
# d DT
#
# time NN
#
# :-D UH
#
# Observances NNS
#
# mark VBP
#
# 9/11 CD
#
# anniversary NN
#
# : :
#
# Observances NNS
#
# in IN
#
# Temecula NNP
#
# and CC
#
# elsewhere RB
#
# throughout IN
#
# the DT
#
# region NN
#
# last JJ
#
# week NN
#
# marked VBD
#
# the DT
#
# ... :
#
# http://dlvr.it/5Rckw URL
#
# RT RT
#
# @jimjonescapo USR
#
# : :
#
# Som1 NN
#
# ask VBP
#
# whn WRB
#
# do VBP
#
# I PRP
#
# sleep VB
#
# : :
#
# when WRB
#
# God NNP
#
# tel VBZ
#
# me PRP
#
# to TO
#
# cum VB
#
# home NN
#
# is VBZ
#
# when WRB
#
# I PRP
#
# wil MD
#
# sleep VB
#
# til IN
#
# thn RB
#
# Im PRP
#
# chasin VBG
#
# n CC
#
# makin VBG
#
# this DT
#
# money NN
#
# to TO
#
# leav VB
#
# ... :
#
# It PRP
#
# 's VBZ
#
# 5pm CD
#
# on IN
#
# Friday NNP
#
# ! .
#
# Wish VBP
#
# you PRP
#
# guys NNS
#
# have VBP
#
# a DT
#
# fabulous JJ
#
# evening NN
#
# !!! .
#
# And CC
#
# have VBP
#
# a DT
#
# wonderful JJ
#
# weekend NN
#
# &lt; UH
#
# 3 UH
#
# &lt; UH
#
# 3 UH
#
# http://fb.me/xLeN7MAe URL
#
# Soulja NNP
#
# Boy NNP
#
# | :
#
# TheDeAndreWay URL
#
# . .
#
# com URL
#
# - :
#
# The NNP
#
# DeAndre NNP
#
# Way NNP
#
# in IN
#
# stores NNS
#
# Nov NNP
#
# . .
#
# 2 CD
#
# , ,
#
# 2010 CD
#
# http://t.co/woAiLlZ URL
#
# via IN
#
# @SouljaBoy USR
#
# Who WP
#
# loves VBZ
#
# Friday NNP
#
# ? .
#
# At IN
#
# the DT
#
# gym NN
#
# now RB
#
# ! .
#
# Excited JJ
#
# for IN
#
# weekend NN
#
# plans NNS
#
# ! .
#
# Time NN
#
# to TO
#
# have VB
#
# #sex HT
#
# Mmmm UH
#
# wings NNS
#
# and CC
#
# beer NN
#
# . .
#
# Damn UH
#
# that WDT
#
# means VBZ
#
# extra JJ
#
# gym NN
#
# time NN
#
# 2mar NN
#
# RT RT
#
# @Huddy85 USR
#
# : :
#
# @Mz_Twilightxxx USR
#
# *kisses VBZ
#
# your PRP$
#
# ass**sneezes NN
#
# after* RB
#
# Lol UH
#
# RT RT
#
# @ajc USR
#
# : :
#
# Today NN
#
# 's VBZ
#
# the DT
#
# 102nd JJ
#
# birthday NN
#
# of IN
#
# the DT
#
# American NNP
#
# Professional NNP
#
# Football NNP
#
# Association NNP
#
# ( (
#
# we PRP
#
# call VBP
#
# it PRP
#
# the DT
#
# NFL) NNP
#
# . .
#
# First JJ
#
# draft NN
#
# choice NN
#
# : :
#
# Brett NNP
#
# Favre NNP
#
# . .
#
# Day NN
#
# One CD
#
# : :
#
# Ten CD
#
# things NNS
#
# you PRP
#
# want VBP
#
# to TO
#
# say VB
#
# to TO
#
# ten CD
#
# different JJ
#
# people NNS
#
# right RB
#
# now RB
#
# - :
#
# 1 LS
#
# ) )
#
# Eduardo NNP
#
# Surita NNP
#
# : :
#
# your PRP
#
# a DT
#
# freaking JJ
#
# ... :
#
# http://tumblr.com/xmciuda0t URL
#
# RT RT
#
# @DesignerDepot USR
#
# : :
#
# Minimalist JJ
#
# Web NN
#
# Design NN
#
# : :
#
# When WRB
#
# Less JJR
#
# is VBZ
#
# More JJR
#
# - :
#
# http://ow.ly/2FwyX URL
#
# Pope NNP
#
# says VBZ
#
# religion NN
#
# ' ''
#
# marginalized': VBN
#
# That WDT
#
# 's VBZ
#
# why WRB
#
# he PRP
#
# ca MD
#
# n't RB
#
# get VB
#
# a DT
#
# headline NN
#
# printed VBN
#
# anywhere RB
#
# , ,
#
# because IN
#
# religion NN
#
# is VBZ
#
# so RB
#
# mar JJ
#
# ... :
#
# http://bit.ly/cBvt1u URL
#
# All DT
#
# night NN
#
# long RB
#
# RT RT
#
# @FauxSuhlenaa USR
#
# : :
#
# I PRP
#
# rape VBP
#
# Nick NNP
#
# Jonas NNP
#
# . .
#
# @lexi_nicole2010 USR
#
# That DT
#
# 's VBZ
#
# not RB
#
# the DT
#
# story NN
#
# by IN
#
# a DT
#
# long JJ
#
# shot NN
#
# biotch UH
#
# ! .
#
# I PRP
#
# have VBP
#
# a DT
#
# strong JJ
#
# hunch NN
#
# Adam NNP
#
# will MD
#
# be VB
#
# a DT
#
# story NN
#
# on IN
#
# TMZ NNP
#
# tonight NN
#
# . .
#
# Gulp UH
#
# . .
#
# Columbus NNP
#
# , ,
#
# GA NNP
#
# : :
#
# @TimmNintey146 USR
#
# and CC
#
# 'll MD
#
# be VB
#
# mixing VBG
#
# an DT
#
# 80 CD
#
# 's POS
#
# and CC
#
# other JJ
#
# throwbacks NNS
#
# dance NN
#
# party NN
#
# tonight NN
#
# at IN
#
# eighty-five JJ
#
# . .
#
# Come VB
#
# kickit VB
#
# ! .
#
# @angelportugues USR
#
# LMAO UH
#
# ! .
#
# When WRB
#
# is VBZ
#
# tht DT
#
# one CD
#
# day NN
#
# ?: UH
#
# P UH
#
# I PRP
#
# 've VBP
#
# just RB
#
# watched VBN
#
# first JJ
#
# four CD
#
# episodes NNS
#
# of IN
#
# K-On NNP
#
# for IN
#
# the DT
#
# first JJ
#
# time NN
#
# ! .
#
# : UH
#
# 3 UH
#
# i PRP
#
# think VBP
#
# it PRP
#
# 's VBZ
#
# better JJR
#
# to TO
#
# go VB
#
# to TO
#
# bed NN
#
# after IN
#
# this DT
#
# bad JJ
#
# day NN
#
# ... :
#
# Love VBP
#
# how WRB
#
# I PRP
#
# ca MD
#
# n't RB
#
# wear VB
#
# my PRP$
# shorts NNS
#
# to TO
#
# the DT
#
# party NN
#
# tonight NN
#
# , ,
#
# so CC
#
# I PRP
#
# have VBP
#
# to TO
#
# wear VB
#
# sweat NN
#
# pants NNS
#
# over IN
#
# them PRP
#
# and CC
#
# change VB
#
# when WRB
#
# I PRP
#
# get VBP
#
# there RB
#
# . .
#
# SmackMyHead UH
#
# . .
#
# Such JJ
#
# a DT
#
# shiny JJ
#
# morning NN
#
# !!! .
#
# Love VBP
#
# It PRP
#
# . .
#
# Anyways UH
#
# , ,
#
# today NN
#
# will MD
#
# be VB
#
# very RB
#
# busy JJ
#
# ! .
#
# Oh UH
#
# lord NNP
#
# here RB
#
# we PRP
#
# go VBP
#
# again RB
#
# Paranormal NNP
#
# Activity NNP
#
# 2 CD
#
# http://j.mp/ascgZr URL
#
# I PRP
#
# 'm VBP
#
# not RB
#
# requesting VBG
#
# it PRP
#
# in IN
#
# my PRP$
#
# area NN
#
# this DT
#
# time NN
#
# . .
#
# Are VBP
#
# you PRP
#
# ? .
#
# RT RT
#
# @HippoArmy USR
#
# : :
#
# Thousands NNS
#
# of IN
#
# angry JJ
#
# masturbators NNS
#
# marched VBD
#
# against IN
#
# Christine NNP
#
# O'Donnell NNP
#
# today NN
#
# http://bit.ly/9nTWQw URL
#
# Seriously UH
#
# . .
#
# Our PRP
#
# Favorite JJ
#
# YouTube NNP
#
# Videos NNS
#
# This DT
#
# Week NN
#
# : :
#
# The DT
#
# Drama NNP
#
# Edition NNP
#
# : :
#
# Had VBD
#
# any DT
#
# epic JJ
#
# meltdowns NNS
#
# this DT
#
# week NN
#
# ? .
#
# You PRP
#
# know VBP
#
# , ,
#
# of IN
#
# the DT
#
# cryin NN
#
# ... :
#
# http://bit.ly/cuy0yt URL
#
# Pedigree NNP
#
# Donates VBZ
#
# Dog NN
#
# Food NN
#
# for IN
#
# Blog NN
#
# Posts NNS
#
# : :
#
# These DT
#
# days NNS
#
# , ,
#
# big JJ
#
# brands NNS
#
# usually RB
#
# look VBP
#
# to TO
#
# the DT
#
# big JJ
#
# social NN
#
# networks NNS
#
# like IN
#
# Face NNP
#
# ... :
#
# http://bit.ly/bYWzrq URL
#
# @jackjohnson USR
#
# where WRB
#
# can MD
#
# I PRP
#
# get VBP
#
# the DT
#
# official JJ
#
# set NN
#
# list NN
#
# to TO
#
# the DT
#
# show NN
#
# at IN
#
# Berkeley NNP
#
# in IN
#
# Oct NNP
#
# 6th CD
#
# ?! .
#
# Check VB
#
# this DT
#
# video NN
#
# out RP
#
# -- :
#
# Three NNP
#
# Days NNP
#
# Grace NNP
#
# - :
#
# Break NNP
#
# ( (
#
# Official JJ
#
# Music NN
#
# Video NN
#
# ) )
#
# [ IN
#
# HQ JJ
#
# ] :
#
# http://t.co/GOwCLQJ URL
#
# via IN
#
# @youtube USR
#
# in IN
#
# tthe DT
#
# Car NN
#
# :/ UH
#
# Today NN
#
# wasz VBD
#
# Fun JJ
#
# cusz IN
#
# anna NNP
#
# Came VBD
#
# juss RB
#
# for IN
#
# me PRP
#
# &lt; UH
#
# 3( UH
#
# : UH
#
# hahaha UH
#
# @angelajames USR
#
# @roxannestclaire USR
#
# I PRP
#
# have VBP
#
# n't RB
#
# tried VBN
#
# MAC NNP
#
# . .
#
# Next JJ
#
# time NN
#
# ! .
#
# friday NNP
#
# night NN
#
# missions NNS
#
# iguess VBP
#
# ! .
#
# LADY NNP
#
# GAGA NNP
#
# IS VBZ
#
# BETTER RBR
#
# THE DT
#
# 5th JJ
#
# TIME NN
#
# OH UH
#
# BABY( UH
#
# : UH
#
# Tryna VBG
#
# Get VB
#
# Into IN
#
# Something NN
#
# Tonight NN
#
# Just RB
#
# got VBD
#
# home NN
#
# from IN
#
# school NN
#
# . .
#
# :D UH
#
# it PRP
#
# 's VBZ
#
# friday NN
#
# guys NNS
#
# !, .
#
# Kid NNP
#
# Cudi NNP
#
# Opens VBZ
#
# Up RP
#
# About IN
#
# Cocaine NN
#
# Use NN
#
# , ,
#
# Failed JJ
#
# Lady NNP
#
# Gaga NNP
#
# Tour NN
#
# : :
#
# by IN
#
# Mariel NNP
#
# Concepcion NNP
#
# , ,
#
# NY NNP
#
# | :
#
# September NNP
#
# 1 CD
#
# ... :
#
# http://bit.ly/cZWGDi URL
#
# RT RT
#
# @RMBWilliams USR
#
# : :
#
# Here RB
#
# in IN
#
# DC NNP
#
# ! .
#
# About RB
#
# to TO
#
# get VB
#
# some DT
#
# rest NN
#
# ! .
#
# Looking VBG
#
# forward RB
#
# to TO
#
# tonight NN
#
# ! .
#
# Yes-sir UH
#
# ! .
#
# holy UH
#
# FUCK UH
#
# THIS DT
#
# IS VBZ
#
# THE DT
#
# MOST JJS
#
# BORING JJ
#
# DAY NN
#
# EVER RB
#
# . .
#
# @NeilPen USR
#
# I PRP
#
# position NN
#
# to TO
#
# Manchester NNP
#
# tomorrow NN
#
# on IN
#
# BA NNP
#
# 2910 CD
#
# and CC
#
# fly VBP
#
# to TO
#
# Barbados NNP
#
# on IN
#
# Sunday NNP
#
# RT RT
#
# @SteevoSupremo USR
#
# : :
#
# #The1906andPearlsShow HT
#
# THIS DT
#
# MONDAY NNP
#
# @ IN
#
# 7:06 CD
#
# : :
#
# 08pm CD
#
# !!!!! .
#
# #MAINBUILDING HT
#
# ROOM NN
#
# . .
#
# 104 CD
#
# !!! .
#
# http://twitpic.com/2oeark URL
#
# SPECIAL JJ
#
# PERF NN
#
# ... :
#
# In IN
#
# bed NN
#
# watching VBG
#
# Day NN
#
# 51 CD
#
# HLs NNP
#
# . .
#
# ( (
#
# Awaiting VBG
#
# Marcus NNP
#
# Bentley NNP
#
# ! .
#
# ) )
#
# #BB11 HT
#
# @Starmaker73 USR
#
# ya UH
#
# but CC
#
# it PRP
#
# would MD
#
# have VB
#
# to TO
#
# go VB
#
# down IN
#
# Saturday NNP
#
# morning NN
#
# and CC
#
# tht WDT
#
# would MD
#
# ntake VB
#
# all DT
#
# day NN
#
# lol UH
#
# so UH
#
# id PRP
#
# be VB
#
# cutting VBG
#
# it PRP
#
# close JJ
#
# lol UH
#
# Our PRP
#
# Favorite JJ
#
# YouTube NNP
#
# Videos NNS
#
# This DT
#
# Week NN
#
# : :
#
# The DT
#
# Drama NNP
#
# Edition NNP
#
# http://dlvr.it/5RfHy URL
#
# i PRP
#
# see VBP
#
# some DT
#
# ppl NN
#
# celebrating VBG
#
# their PRP$
#
# birthdays NNS
#
# like IN
#
# 2-3 CD
#
# times NNS
#
# a DT
#
# year NN
#
# ... :
#
# WTF UH
#
# ?! .
#
# @TRARONEdwards USR
#
# tuesday NNP
#
# is VBZ
#
# perfecy JJ
#
# WIN VB
#
# FREE JJ
#
# PAMPERS NNS
#
# FOR IN
#
# A DT
#
# YEAR NN
#
# !!! .
#
# And CC
#
# more JJ
#
# ... :
#
# http://nblo.gs/80qJu URL
#
# today NN
#
# is VBZ
#
# my PRP$
#
# last JJ
#
# day NN
#
# at IN
#
# the DT
#
# office NN
#
# . .
#
# Stop VBP
#
# by IN
#
# the DT
#
# COLLEGE NNP
#
# REPUBLICAN NNP
#
# TAILGATE NNP
#
# tomorrow NN
#
# @ IN
#
# 9:30 CD
#
# in IN
#
# Yellow NNP
#
# Lot NNP
#
# 17 CD
#
# for IN
#
# FOOD NN
#
# before IN
#
# the DT
#
# game NN
#
# RT RT
#
# @OscarBlandi USR
#
# : :
#
# That DT
#
# time NN
#
# again RB
#
# ! .
#
# #FreebieFriday HT
#
# Be VBP
#
# the DT
#
# 15th JJ
#
# RT RT
#
# & CC
#
# get VBP
#
# your PRP$
#
# hands NNS
#
# on IN
#
# a DT
#
# free JJ
#
# travel NN
#
# size NN
#
# pronto NN
#
# invisible JJ
#
# dry JJ
#
# shampoo NN
#
# ! .
#
# Oh UH
#
# yeah UH
#
# ! .
#
# Probably RB
#
# hairdresser NN
#
# tomorrow NN
#
# , ,
#
# and CC
#
# for IN
#
# sure JJ
#
# meet VB
#
# Levin NNP
#
# , ,
#
# Hien NNP
#
# &lt; UH
#
# 3 UH
#
# and CC
#
# Fabi NNP
#
# . .
#
# 'll MD
#
# have VB
#
# a DT
#
# great JJ
#
# daaaaay NN
#
# &lt; UH
#
# 33 UH
#
# RT RT
#
# @SonyElectronics USR
#
# : :
#
# Sony/Bud NNP
#
# Light NNP
#
# 3D NN
#
# tailgate NN
#
# parties NNS
#
# on IN
#
# Saturday NNP
#
# - :
#
# Clemson NNP
#
# party NN
#
# at IN
#
# http://bit.ly/cds8Pd URL
#
# ; :
#
# Auburn NNP
#
# party NN
#
# at IN
#
# http://bit URL
#
# . .
#
# ... :
#
# I PRP
#
# may MD
#
# have VB
#
# been VBN
#
# wrong JJ
#
# about IN
#
# Murkowski NNP
#
# , ,
#
# look VB
#
# like IN
#
# she PRP
#
# 's VBZ
#
# going VBG
#
# to TO
#
# turn VB
#
# Friday NNP
#
# news NN
#
# dump NN
#
# on IN
#
# its PRP$
#
# head NN
#
# . .
#
# three-way JJ
#
# race NN
#
# reportedly RB
#
# ahead RB
#
# in IN
#
# AK NNP
#
# . .
#
# I PRP
#
# 've VBP
#
# got VBN
#
# a DT
#
# theory NN
#
# that IN
#
# if IN
#
# you PRP
#
# give VBP
#
# 100% NN
#
# all DT
#
# of IN
#
# the DT
#
# time NN
#
# , ,
#
# somehow RB
#
# things NNS
#
# will MD
#
# work VB
#
# out RP
#
# in IN
#
# the DT
#
# end NN
#
# . .
#
# -Larry NNP
#
# Bird NNP
#
# I PRP
#
# have VBP
#
# lost VBN
#
# everything NN
#
# importing JJ
#
# in IN
#
# my PRP$
#
# life NN
#
# within IN
#
# the DT
#
# past JJ
#
# week NN
#
# anything NN
#
# that WDT
#
# i PRP
#
# loved VBD
#
# is VBZ
#
# now RB
#
# gone VBN
#
# Hit VBP
#
# word NN
#
# count NN
#
# ! .
#
# Woo-hoo UH
#
# ! .
#
# *throwing VBG
#
# confetti* NN
#
# Now RB
#
# I PRP
#
# can MD
#
# goof VB
#
# off RP
#
# tonight NN
#
# and CC
#
# read VB
#
# . .
#
# *happy JJ
#
# writer NN
#
# dance* NN
#
# #amwriting HT
#
# #havewritten-yay HT
#
# ! .
#
# Korean NNP
#
# War NNP
#
# spy NN
#
# rivalries NNS
#
# persist VBP
#
# 60 CD
#
# years NNS
#
# later JJ
#
# : :
#
# Far RB
#
# be VB
#
# it PRP
#
# that IN
#
# the DT
#
# week NN
#
# should MD
#
# pass VB
#
# without IN
#
# noting VBG
#
# that IN
#
# it PRP
#
# was VBD
#
# 60 CD
#
# ... :
#
# http://bit.ly/cCjFBm URL
#
# It PRP
#
# is VBZ
#
# Friday NNP
#
# afternoon NN
#
# adn CC
#
# I PRP
#
# could MD
#
# n't RB
#
# be VB
#
# happier JJR
#
# . .
#
# Ending VBG
#
# a DT
#
# crappy JJ
#
# week NN
#
# on IN
#
# a DT
#
# good JJ
#
# note NN
#
# is VBZ
#
# always RB
#
# nice JJ
#
# . .
#
# @MrzEndy USR
#
# tru UH
#
# tru UH
#
# I PRP
#
# 'm VBP
#
# leavin VBG
#
# again RB
#
# on IN
#
# Tuesday NNP
#
# yo UH
#
# by IN
#
# my PRP$
#
# lonesome NN
#
# tonight NN
#
# .... :
#
# #obsessions HT
#
# The DT
#
# guys NNS
#
# are VBP
#
# cooking VBG
#
# about IN
#
# a DT
#
# dozen NN
#
# pizzas NNS
#
# at IN
#
# our PRP$
#
# house NN
#
# for IN
#
# the DT
#
# tailgate NN
#
# tonight NN
#
# . .
#
# Nonetheless RB
#
# it PRP
#
# smells VBZ
#
# fresh JJ
#
# in IN
#
# this DT
#
# place NN
#
# . .
#
# I PRP
#
# heart VBP
#
# Park(ing NNP
#
# ) )
#
# Day NNP
#
# ! .
#
# Photo NN
#
# of IN
#
# meter NN
#
# shark NN
#
# : :
#
# http://bit.ly/aQun1b URL
#
# hows WRB
#
# everyones PRP$
#
# day NN
#
# goin VBG
#
# ? .
#
# Going VBG
#
# to TO
#
# start VB
#
# #HelloMornings HT
#
# on IN
#
# Oct NNP
#
# 1 CD
#
# - :
#
# Check VB
#
# it PRP
#
# out RP
#
# on IN
#
# @michellebygrace USR
#
# @Phoebe1_ USR
#
# and CC
#
# i PRP
#
# also RB
#
# loved VBD
#
# the DT
#
# last JJ
#
# years NNS
#
# eurovision NN
#
# entry NN
#
# !! .
#
# hoppaa UH
#
# ! .
#
# they PRP
#
# were VBD
#
# cool JJ
#
# too RB
#
# !! .
#
# ; :
#
# I PRP
#
# can MD
#
# upgrade VB
#
# to TO
#
# a DT
#
# BlackBerry NNP
#
# in IN
#
# November NNP
#
# !! .
#
# Yesss UH
#
# . .
#
# &lt; UH
#
# 3 UH
#
# BB NNP
#
# Bold NNP
#
# , ,
#
# here RB
#
# I PRP
#
# come VBP
#
# ! .
#
# @_Kinghoopa USR
#
# the DT
#
# one CD
#
# thats WDT
#
# out JJ
#
# now RB
#
# is VBZ
#
# free JJ
#
# ... :
#
# Father NN
#
# to TO
#
# tha DT
#
# Game NN
#
# is VBZ
#
# droppin VBG
#
# in IN
#
# a DT
#
# month NN
#
# or CC
#
# so RB
#
# .. :
#
# A DT
#
# TRUE JJ
#
# friend NN
#
# walks VBZ
#
# in IN
#
# when WRB
#
# everybody NN
#
# else RB
#
# walks VBZ
#
# out RP
#
# ! .
#
# @lauraluanabeth USR
#
# 'll MD
#
# be VB
#
# back RB
#
# in IN
#
# LA NNP
#
# tomorrow NN
#
# night NN
#
# ! .
#
# yaaaay UH
#
# ! .
#
# Do VB
#
# n't RB
#
# Have VB
#
# Time NN
#
# To TO
#
# Stop VB
#
# In RP
#
# ??? .
#
# Then RB
#
# , ,
#
# Check VB
#
# Out RP
#
# Our PRP$
#
# Quick JJ
#
# Full JJ
#
# Service JJ
#
# Drive NN
#
# Thru NN
#
# Window NN
#
# :) UH
#
# today NN
#
# seems VBZ
#
# like IN
#
# a DT
#
# good JJ
#
# day NN
#
# to TO
#
# chill VB
#
# :) UH
#
# the DT
#
# tears NNS
#
# may MD
#
# have VB
#
# been VBN
#
# and CC
#
# gone VBN
#
# , ,
#
# but CC
#
# the DT
#
# feeling NN
#
# still RB
#
# stay VB
#
# the DT
#
# same JJ
#
# . .
#
# Still RB
#
# on IN
#
# my PRP$
#
# @teganandsara USR
#
# kick NN
#
# ! .
#
# It PRP
#
# 's VBZ
#
# been VBN
#
# a DT
#
# solid JJ
#
# 2 CD
#
# weeks NNS
#
# ! .
#
# Chilling VBG
#
# wit IN
#
# my PRP$
#
# baby NN
#
# tonight NN
#
# ! .
#
# @abzmedic USR
#
# I PRP
#
# 'm VBP
#
# missing VBG
#
# autumn NN
#
# because IN
#
# of IN
#
# work NN
#
# . .
#
# :( UH
#
# I PRP
#
# must MD
#
# get VB
#
# into IN
#
# the DT
#
# forests NNS
#
# tomorrow NN
#
# ! .
#
# #woot HT
#
# I'd PRP
#
# like VB
#
# to TO
#
# buy VB
#
# this DT
#
# , ,
#
# but CC
#
# i PRP
#
# have VBP
#
# a DT
#
# hard JJ
#
# time NN
#
# doing VBG
#
# a TD
#
# sit NN
#
# up NN
#
# ... :
#
# RT RT
#
# @Sexstrology USR
#
# : :
#
# Pisces NNS
#
# tend VBP
#
# to TO
#
# escape VB
#
# into IN
#
# fantasy NN
#
# and JJ
#
# day NN
#
# dreams NNS
#
# . .
#
# There RB
#
# they PRP
#
# are VBP
#
# free JJ
#
# . .
#
# Cant MD
#
# wait VB
#
# for IN
#
# the DT
#
# ravens NNP
#
# game NN
#
# tomorrow NN
#
# .... :
#
# go VB
#
# ray NNP
#
# rice NNP
#
# !!!!!!! .
#
# @PERSONGUY6661 USR
#
# I PRP
#
# have VBP
#
# n't RB
#
# unfortunately JJ
#
# :( UH
#
# I PRP
#
# missed VBD
#
# the DT
#
# chance NN
#
# when WRB
#
# theycame VB
#
# to TO
#
# the DT
#
# uk USR
#
# this DT
#
# year NN
#
# , ,
#
# you PRP
#
# seen VBZ
#
# them PRP
#
# ? .
#
# Stephen NNP
#
# , ,
#
# the DT
#
# Intellectual NNP
#
# . .
#
# @bbhess USR
#
# I PRP
#
# bet VBP
#
# ppl NNS
#
# that DT
#
# design VB
#
# book NN
#
# covers NNS
#
# for IN
#
# a DT
#
# living NN
#
# hate VBP
#
# when WRB
#
# people NNS
#
# say VBP
#
# do VBP
#
# n't RB
#
# judge VB
#
# a DT
#
# book NN
#
# by IN
#
# its PRP$
#
# cover NN
#
# I PRP
#
# miss VBP
#
# being VBG
#
# able JJ
#
# to TO
#
# run VB
#
# and CC
#
# dance VB
#
# around RP
#
# all DT
#
# day NN
#
# instead RB
#
# of IN
#
# having VBG
#
# to TO
#
# catch VB
#
# my PRP$
#
# breath NN
#
# every DT
#
# five CD
#
# minutes NNS
#
# of IN
#
# my PRP$
#
# life NN
#
# . .
# Is VBZ
#
# all DT
#
# done VBN
#
# getting VBG
#
# things NNS
#
# set VB
#
# up RP
#
# for IN
#
# the DT
#
# Ultimate NNP
#
# Magic NNP
#
# playtest NN
#
# that WDT
#
# starts VBZ
#
# on IN
#
# Monday NNP
#
# . .
#
# Ca MD
#
# n't RB
#
# wait VB
#
# to TO
#
# see VB
#
# what WP
#
# people NNS
#
# think VBP
#
# . .
#
# I PRP
#
# 've VBP
#
# never RB
#
# found VBN
#
# a DT
#
# happy JJ
#
# way NN
#
# to TO
#
# preserve VB
#
# it PRP
#
# but CC
#
# it PRP
#
# 's VBZ
#
# usually RB
#
# affordable JJ
#
# most JJS
#
# of IN
#
# the DT
#
# year NN
#
# . .
#
# We PRP
#
# eat VBP
#
# a DT
#
# lot NN
#
# 2 RB
#
# , ,
#
# grilled JJ
#
# saute JJ
#
# bake JJ
#
# or CC
#
# fried JJ
#
# RT RT
#
# @LilTwist USR
#
# : :
#
# RT RT
#
# this DT
#
# if IN
#
# you PRP
#
# want VBP
#
# me PRP
#
# to TO
#
# go VB
#
# back RB
#
# live RB
#
# on IN
#
# Ustream NNP
#
# later RB
#
# tonight NN
#
# Have VB
#
# DJ NN
#
# Got VBZ
#
# Us PRP
#
# Fallin VBG
#
# in IN
#
# Love NN
#
# in IN
#
# my PRP$
#
# head NN
#
# . .
#
# " ''
#
# Cause IN
#
# baby NN
#
# tonight NN
#
# , ,
#
# The DT
#
# dj NN
#
# got VBZ
#
# us PRP
#
# fallin VBG
#
# in IN
#
# love NN
#
# again RB
#
# " ''
#
# @Littlesapling USR
#
# You PRP
#
# said VBD
#
# that DT
#
# last JJ
#
# week NN
#
# Ash NNP
#
# . .
#
# I PRP
#
# think VBP
#
# you PRP
#
# need VBP
#
# a DT
#
# 12 CD
#
# step NN
#
# program NN
#
# . .
#
# How WRB
#
# to TO
#
# Write VB
#
# a DT
#
# Resume NN
#
# After IN
#
# Being VBG
#
# Fired VBN
#
# : :
#
# Dealing VBG
#
# with IN
#
# how WRB
#
# to TO
#
# write VB
#
# a DT
#
# resume NN
#
# after IN
#
# being VBG
#
# fired NN
#
# is VBZ
#
# something NN
#
# many NNS
#
# of IN
#
# ... :
#
# http://bit.ly/amRxFJ URL
#
# Amber NNP
#
# Le NNP
#
# Bon NNP
#
# is VBZ
#
# to TO
#
# walk VB
#
# in IN
#
# Giles NNP
#
# Deacon NNP
#
# 's POS
#
# Monday NNP
#
# LFW NNP
#
# show NN
#
# @KFSH USR
#
# totally UH
#
# ! .
#
# I PRP
#
# can MD
#
# go VB
#
# a DT
#
# week NN
#
# w/o IN
#
# tv NN
#
# , ,
#
# phones NNS
#
# or CC
#
# a DT
#
# computer NN
#
# . .
#
# I PRP
#
# get VBP
#
# some DT
#
# time NN
#
# to TO
#
# myself PRP
#
# and CC
#
# God NNP
#
# . .
#
# Brings VBZ
#
# peace NN
#
# into IN
#
# my PRP$
#
# life NN
#
# . .
#
# last JJ
#
# day NN
#
# of IN
#
# sorting VBG
#
# pope NNP
#
# visit NN
#
# to TO
#
# birmingham NNP
#
# stuff NN
#
# out RP
#
# ..... :
#
# hope VBP
#
# it PRP
#
# goes VBZ
#
# ok JJ
#
# on IN
#
# sunday NNP
#
# !! .
#
# Lmao UH
#
# .. :
#
# They PRP
#
# #Hurrt HT
#
# ! :
#
# RT RT
#
# @_sofucKENNrude USR
#
# y WRB
#
# every DT
#
# nigga NN
#
# tryna VBG
#
# grow VB
#
# they PRP$
#
# hair NN
#
# out RP
#
# . .
#
# should MD
#
# of NN
#
# did VBD
#
# that DT
#
# a DT
#
# long JJ
#
# time NN
#
# ago IN
#
# . .
#
# -_- UH
#
# skimp JJ
#
# ass JJ
#
# braids NNS
#
# . .
#
# RT RT
#
# @TomsTop5 USR
#
# : :
#
# Check VB
#
# us PRP
#
# out RP
#
# - :
#
# we PRP
#
# 're VBP
#
# FEATURED VBN
#
# on IN
#
# iTunes NNP
#
# this DT
#
# week NN
#
# ! .
#
# Make VB
#
# sure JJ
#
# to TO
#
# subscribe VB
#
# so IN
#
# Jobs NNP
#
# knows VBZ
#
# you PRP
#
# love VBP
#
# us PRP
#
# http://twitpic.com/2pdr8h URL
#
# just RB
#
# about RB
#
# off RB
#
# work NN
#
# ! .
#
# going VBG
#
# to TO
#
# alderwood NNP
#
# again RB
#
# :) UH
#
# yay UH
#
# . .
#
# hopefully RB
#
# we PRP
#
# got VBD
#
# cody NNP
#
# 's POS
#
# ipod NN
#
# in IN
#
# the DT
#
# mail NN
#
# today NN
#
# . .
#
# @justinbieber USR
#
# I PRP
#
# have VBP
#
# chance NN
#
# with IN
#
# you PRP
#
# ? .
#
# webcam NN
#
# enters VBZ
#
# Sunday NNP
#
# 7:00 CD
#
# pm JJ
#
# ? .
#
# please UH
#
# ? .
#
# to TO
#
# talk VB
#
# right RB
#
# ! .
#
# kisses NNS
#
# on IN
#
# the DT
#
# chin NN
#
# Its PRP
#
# stupid JJ
#
# I PRP
#
# hate VBP
#
# getn VBG
#
# a DT
#
# attitude NN
#
# from IN
#
# ppl NNS
#
# when WRB
#
# I PRP
#
# 'm VBP
#
# jus RB
#
# tryna VBG
#
# be VB
#
# nice JJ
#
# n CC
#
# shit NN
#
# . .
#
# WTF UH
#
# now RB
#
# I PRP
#
# 'm VBP
#
# mad JJ
#
# so IN
#
# dnt VB
#
# talk VB
#
# to TO
#
# me PRP
#
# right RB
#
# now RB
#
# RT RT
#
# @DamnTeenQuotes USR
#
# : :
#
# I PRP
#
# remember VBP
#
# when WRB
#
# i PRP
#
# was VBD
#
# your PRP$
#
# age NN
#
# , ,
#
# spencer NNP
#
# from IN
#
# iCarly NNP
#
# was VBD
#
# Crazy NNP
#
# Steve NNP
#
# , ,
#
# Carly NNP
#
# was VBD
#
# Megan NNP
#
# and CC
#
# Josh NNP
#
# was VBD
#
# fat NN
#
# . .
#
# #damnteenquotes HT
#
# @itzkeving USR
#
# im PRP
#
# getting VBG
#
# mine PRP$
#
# off RB
#
# this DT
#
# monday NNP
#
# :' UH
#
# ) )
#
# Israel NNP
#
# grinds VBZ
#
# to TO
#
# a DT
#
# halt NN
#
# for IN
#
# Yom NNP
#
# Kippur NNP
#
# fasting JJ
#
# day NN
#
# ( (
#
# wwrn.org URL
#
# ) )
#
# http://bit.ly/cqlwCZ URL
#
# #Fancyflow HT
#
# .. :
#
# im PRP
#
# in IN
#
# the DT
#
# hair NN
#
# salon NN
#
# right RB
#
# now RB
#
# ...
#
# Celebration NN
#
# ! .
#
# ... :
#
# @StarJonesEsq USR
#
# just RB
#
# shocked VBD
#
# me PRP
#
# for IN
#
# the DT
#
# second JJ
#
# time NN
#
# .. :
#
# she PRP
#
# 's VBZ
#
# a DT
#
# lawyer NN
#
# !? .
#
# LOL UH
#
# . .
#
# No UH
#
# tell VB
#
# me PRP
#
# it PRP
#
# 's VBZ
#
# April NNP
#
# 1st CD
#
# right RB
#
# now RB
#
# . .
#
# Y WRB
#
# iis VBZ
#
# Love NN
#
# so RB
#
# strong JJ
#
# .. :
#
# y WRB
#
# ca MD
#
# n't RB
#
# you PRP
#
# say VBP
#
# fuck UH
#
# iit UH
#
# when WRB
#
# you PRP
#
# want VBP
#
# too TO
#
# ??? .
#
# This DT
#
# will MD
#
# be VB
#
# a DT
#
# great JJ
#
# week NN
#
# hell UH
#
# a DT
#
# great JJ
#
# month NN
#
# @MeredithLim USR
#
# No UH
#
# . .
#
# Tomorrow NN
#
# . .
#
# CIty NN
#
# Sponsors VBZ
#
# Drug NN
#
# Toss NN
#
# To TO
#
# Dispose VB
#
# Of IN
#
# Expired JJ
#
# Medications NNS
#
# : :
#
# Louisville NNP
#
# and CC
#
# several JJ
#
# partners NNS
#
# are VBP
#
# offering VBG
#
# three CD
#
# days NNS
#
# ... :
#
# http://bit.ly/bbUSMP URL
#
# October NNP
#
# is VBZ
#
# Breast NNP
#
# Cancer NNP
#
# Awareness NNP
#
# month NN
#
# - :
#
# a DT
#
# portion NN
#
# of IN
#
# the DT
#
# proceeds NNS
#
# from IN
#
# purchase NN
#
# of IN
#
# this DT
#
# beautiful JJ
#
# diamond NN
#
# ... :
#
# http://fb.me/B680RuaH URL
#
# @Freyza_ USR
#
# oh UH
#
# thats DT
#
# not RB
#
# so RB
#
# bad JJ
#
# then RB
#
# ? .
#
# And CC
#
# , ,
#
# what WP
#
# time NN
#
# do VBP
#
# you PRP
#
# get VBP
#
# off RP
#
# ? .
#
# No DT
#
# bike NN
#
# t'day NN
#
# :( UH
#
# @BrianNeudorff USR
#
# I PRP
#
# have VBP
#
# n't RB
#
# seen VBN
#
# it PRP
#
# in IN
#
# so RB
#
# long RB
#
# ! .
#
# I PRP
#
# 'm VBP
#
# overdue JJ
#
# for IN
#
# some DT
#
# thundersnow NNP
#
# RT RT
#
# @KamilleLeai USR
#
# : :
#
# Even RB
#
# when WRB
#
# u PRP
#
# have VBP
#
# no DT
#
# job NN
#
# , ,
#
# monday NNP
#
# 's POS
#
# still RB
#
# suck VB
#
# lol UH
#
# corrr NN
#
# about IN
#
# , ,
#
# ' ''
#
# bet VBP
#
# id PRP
#
# have VB
#
# money NN
#
# then RB
#
# ' ''
#
# obviously RB
#
# its PRP
#
# ma PRP$
#
# bday NN
#
# like IN
#
# i PRP
#
# wont MD
#
# get VB
#
# bday NN
#
# money NN
#
# lool UH
#
# some DT
#
# ppl NNS
#
# make VBP
#
# me PRP
#
# lol UH
#
# , ,
#
# hard JJ
# time NN
#
# these DT
#
# days NNS
#
# man NN
#
# It PRP
#
# was VBD
#
# just RB
#
# the DT
#
# best JJS
#
# day NN
#
# of IN
#
# my PRP$
#
# life NN
#
# .. :
#
# thanks NNS
#
# to TO
#
# some DT
#
# people NNS
#
# and CC
#
# the DT
#
# unknown JJ
#
# old JJ
#
# lady NN
#
# for IN
#
# sharing VBG
#
# her PRP$
#
# experience NN
#
# __AND__ CC
#
# advice NN
#
# ... :
#
# @pegasus_za USR
#
# You PRP
#
# 're VBP
#
# welcome JJ
#
# . .
#
# Yeah UH
#
# , ,
#
# it PRP
#
# 's VBZ
#
# not RB
#
# a DT
#
# bad JJ
#
# day NN
#
# , ,
#
# just RB
#
# feeling VBG
#
# a DT
#
# little RB
#
# tired JJ
#
# and CC
#
# ill PRP
#
# . .
#
# How WRB
#
# 's VBZ
#
# it PRP
#
# going VBG
#
# with IN
#
# you PRP
#
# ? .
#
# Think VBP
#
# I'ma PRP
#
# make VB
#
# @GrownWomanStuff USR
#
# have VBP
#
# a DT
#
# shoegasm NN
#
# today NN
#
# hahahaha UH
#
# RT RT
#
# @politicalwind USR
#
# : :
#
# Congress NNP
#
# punts NNS
#
# tough JJ
#
# choice NN
#
# until IN
#
# after IN
#
# election NN
#
# http://bit.ly/aEi59e URL
#
# #oreillyfactor HT
#
# Shower NN
#
# time NN
#
# the DT
#
# flyin NNP
#
# pilot NNP
#
# I PRP
#
# was VBD
#
# at IN
#
# last JJ
#
# night NN
#
# did VBD
#
# n't RB
#
# have VB
#
# no DT
#
# hot JJ
#
# water NN
#
# uggghh UH
#
# @gabbysueurban USR
#
# WELL UH
#
# seems VBZ
#
# like IN
#
# you PRP
#
# had VBD
#
# a DT
#
# fantastic JJ
#
# time NN
#
# !!! .
#
# lol UH
#
# MISSED VBD
#
# YAH PRP
#
# ! .
#
# :) UH
#
# ttys UH
#
# enough RB
#
# assassins NNP
#
# creed NNP
#
# for IN
#
# today NN
#
# , ,
#
# now RB
#
# its PRP
#
# time NN
#
# for IN
#
# some DT
#
# homework NN
#
# , ,
#
# and CC
#
# a DT
#
# chocolate NN
#
# milkshake NN
#
# :D UH
#
# Most JJS
#
# things NNS
#
# usually RB
#
# do VB
#
# RT RT
#
# @johncabell USR
#
# Somehow RB
#
# it PRP
#
# seems VBZ
#
# a DT
#
# much RB
#
# more RBR
#
# sensible JJ
#
# idea NN
#
# when WRB
#
# @mccanner USR
#
# suggests VBZ
#
# it PRP
#
# . .
#
# Dude NN
#
# in IN
#
# my PRP$
#
# group NN
#
# in IN
#
# my PRP$
#
# Bcom NN
#
# class NN
#
# invited VBD
#
# me PRP
#
# to TO
#
# an DT
#
# Evangelist NN
#
# revival NN
#
# mass NN
#
# ... :
#
# FUCKING RB
#
# HATE VBP
#
# IT PRP
#
# WHEN WRB
#
# THEY PRP
#
# KNOW VBP
#
# I'M PRP
#
# PAGAN NNP
#
# AND CC
#
# INVITE VBP
#
# ME PRP
#
# . .
#
# ANGER NN
#
# . .
#
# We PRP
#
# should MD
#
# be VB
#
# launching VBG
#
# our PRP$
#
# first JJ
#
# street NN
#
# team NN
#
# promotion NN
#
# today NN
#
# . .
#
# Stay VB
#
# tuned VBN
#
# ! .
#
# http://tinyurl.com/22kset2 URL
#
# Very RB
#
# grateful JJ
#
# for IN
#
# another DT
#
# Monday NNP
#
# and CC
#
# a DT
#
# new JJ
#
# week NN
#
# full JJ
#
# of IN
#
# endless JJ
#
# possibilities NNS
#
# ! .
#
# Go VB
#
# World NN
#
# ! .
#
# SCORES NNS
#
# WEEK NN
#
# #4 HT
#
# http://bit.ly/cDuurY URL
#
# New JJ
#
# Hannah NNP
#
# Montana NNP
#
# tonight NN
#
# !!! .
#
# :D UH
#
# wow UH
#
# I PRP
#
# 'm VBP
#
# way RB
#
# to TO
#
# excited JJ
#
# are VBP
#
# n't RB
#
# I PRP
#
# ? .
#
# tomorrow NN
#
# no DT
#
# school NN
#
# for IN
#
# me PRP
#
# but CC
#
# I PRP
#
# 'm VBP
#
# so RB
#
# anxious JJ
#
# beacuse IN
#
# of IN
#
# tomorrow NN
#
# omg UH
#
# :/ UH
#
# Happy JJ
#
# 1 CD
#
# month NN
#
# anniversary NN
#
# to TO
#
# my PRP$
#
# wonderful JJ
#
# wife NN
#
# @lizwoodring USR
#
# !!! .
#
# I PRP
#
# finished VBD
#
# it PRP
#
# before IN
#
# the DT
#
# bell NN
#
# rang VBD
#
# , ,
#
# just RB
#
# after IN
#
# the DT
#
# bell NN
#
# started VBD
#
# ringing VBG
#
# ..! .
#
# I PRP
#
# sware VBP
#
# ! .
#
# @biancalilly USR
#
# ahaha UH
#
# ! .
#
# Omg UH
#
# Bianca NNP
#
# , ,
#
# that DT
#
# made VBD
#
# my PRP$
#
# day NN
#
# ! .
#
# all DT
#
# night NN
#
# email-athon NN
#
# ! .
#
# really RB
#
# need VBP
#
# to TO
#
# catch VB
#
# up RP
#
# - :
#
# if IN
#
# you PRP
#
# 've VBP
#
# been VBN
#
# waiting VBG
#
# for IN
#
# a DT
#
# reply NN
#
# all DT
#
# summer NN
#
# tonight NN
#
# is VBZ
#
# YOUR PRP$
#
# night NN
#
# ! .
#
# RT RT
#
# @Yale USR
#
# : :
#
# RT RT
#
# @YaleSOM USR
#
# : :
#
# Will MD
#
# government NN
#
# or CC
#
# markets NNS
#
# finance VBP
#
# sustainability NN
#
# ? .
#
# A DT
#
# free JJ
#
# webinar NN
#
# on IN
#
# Oct NNP
#
# . .
#
# 6 CD
#
# . .
#
# http://bit.ly/YaleSOMwebinar URL
#
# RT RT
#
# @UWEauClaire USR
#
# : :
#
# It PRP
#
# 's VBZ
#
# Fire NNP
#
# Prevention NNP
#
# Week NNP
#
# 2010 CD
#
# . .
#
# Review VB
#
# these DT
#
# home NN
#
# prevention NN
#
# guidelines NNS
#
# http://bit.ly/ahmX6b URL
#
# and CC
#
# watch VB
#
# this DT
#
# video NN
#
# http URL
#
# : :
#
# ... :
#
# Part NN
#
# of IN
#
# me PRP
#
# always RB
#
# thinks VBZ
#
# life NN
#
# will MD
#
# slow VB
#
# down RP
#
# in IN
#
# the DT
#
# fall NN
#
# , ,
#
# but CC
#
# it PRP
#
# feels VBZ
#
# far RB
#
# from IN
#
# it PRP
#
# ! .
#
# Time NN
#
# to TO
#
# sync VB
#
# up RP
#
# my PRP$
#
# calendars NNS
#
# soon RB
#
# y'all PRP
#
# care VBP
#
# if IN
#
# I PRP
#
# do VBP
#
# a DT
#
# countdown NN
#
# to TO
#
# #wku HT
#
# homecoming NN
#
# ? .
#
# ok UH
#
# , ,
#
# no UH
#
# ? .
#
# 26 CD
#
# days NNS
#
# Volleyball NN
#
# player NN
#
# Stephanie NNP
#
# Rogers NNP
#
# and CC
#
# cross NN
#
# country NN
#
# runner NN
#
# Matt NNP
#
# Brooker NNP
#
# named VBD
#
# Cedarville NNP
#
# SUBWAY NNP
#
# Athetes NNP
#
# of IN
#
# the DT
#
# Week NN
#
# ( (
#
# 9/26-10/2) CD
#
# . .
#
# ... :
#
# Good JJ
#
# day NN
#
# at IN
#
# school NN
#
# ,! .
#
# Getting VBG
#
# the DT
#
# bus NN
#
# home NN
#
# from IN
#
# school NN
#
# was VBD
#
# even RB
#
# funnyer JJR
#
# :D UH
#
# xHahaa UH
#
# !! .
#
# ;) UH
#
# x UH
#
# @ms_gee USR
#
# Happy JJ
#
# B NN
#
# Day NN
#
# ... :
#
# @enaj USR
#
# @autoclavicle USR
#
# we PRP
#
# saw VBD
#
# one CD
#
# last JJ
#
# Sun NNP
#
# morn NN
#
# in IN
#
# St NNP
#
# Paul NNP
#
# . .
#
# Only JJ
#
# time NN
#
# I PRP
#
# thought VBD
#
# it PRP
#
# could MD
#
# be VB
#
# fun JJ
#
# . .
#
# Brunch NN
#
# crawl NN
#
# . .
#
# FUCK VB
#
# 3D NN
#
# !!!! .
#
# They PRP
#
# going VBG
#
# to TO
#
# remake VB
#
# every DT
#
# single JJ
#
# one CD
#
# of IN
#
# the DT
#
# starwars NNP
#
# movies NNS
#
# in IN
#
# 3D CD
#
# and CC
#
# show VB
#
# new JJ
#
# one CD
#
# every DT
#
# year NN
#
# from IN
#
# 2012 CD
#
# till IN
#
# 2017 CD
#
# . .
#
# FUCK VB
#
# YOU PRP
#
# 3D NN
#
# ! .
#
# RT RT
#
# @malikismusic USR
#
# : :
#
# #TEAMPOSITIVITY HT
#
# ALL DT
#
# DAY NN
#
# !!!! .
#
# RETWEET VB
#
# !!! .
#
# Tomorrow NN
#
# is VBZ
#
# the DT
#
# last JJ
#
# day NN
#
# to TO
#
# join VB
#
# our PRP$
#
# team NN
#
# as IN
#
# we PRP
#
# " ''
#
# Race VB
#
# for IN
#
# the DT
#
# Cure NN
#
# "!! .
#
# Please VB
#
# follow VB
#
# the DT
#
# instructions NNS
#
# below IN
#
# to TO
#
# ... :
#
# http://fb.me/HdvXNndg URL
#
# @Exclusively_T USR
#
# it PRP
#
# came VBD
#
# on IN
#
# my PRP$
#
# pandora NNP
#
# today NN
#
# tho RB
#
# loser NN
#
# so IN
#
# I PRP
#
# tweeted VBD
#
# it PRP
#
# , ,
#
# nobody NN
#
# stuntin VBG
#
# yo PRP$
#
# tweet NN
#
# well UH
#
# i PRP
#
# will MD
#
# be VB
#
# back RB
#
# later RB
#
# no DT
#
# doubt NN
#
# , ,
#
# its PRP
#
# feeding VBG
#
# time NN
#
# at IN
#
# the DT
#
# zoo NN
#
# !! .
#
# See VB
#
# 'll PRP
#
# later RB
#
# ! .
#
# xx UH
#
# It PRP
#
# 's VBZ
#
# time NN
#
# to TO
#
# leave VB
#
# . .
#
# Thanks NNS
#
# for IN
#
# the DT
#
# roller NN
#
# coaster NN
#
# ride NN
#
# it PRP
#
# 's VBZ
#
# been VBN
#
# interesting JJ
#
# but CC
#
# excruciatingly RB
#
# painful JJ
#
# !! .
#
# @lesanto USR
#
# have VB
#
# a DT
#
# look NN
#
# at IN
#
# http://facebook.com/media14 URL
#
# , ,
#
# there EX
#
# are VBP
#
# postings NNS
#
# from IN
#
# TechCrunch NNP
#
# and CC
#
# Flowtown NNP
#
# that DT
#
# may MD
#
# help VB
#
# #mobile HT
#
# RT RT
#
# @jakeandamir USR
#
# : :
#
# THIS DT
#
# TWEET NN
#
# IS VBZ
#
# FOR IN
#
# MY PRP$
#
# EYES NNS
#
# ONLY RB
#
# ! .
#
# PLEASE VB
#
# STOP VB
#
# READING VBG
#
# ! .
#
# Hey UH
#
# Amir NNP
#
# , ,
#
# in IN
#
# case NN
#
# you PRP
#
# ever RB
#
# forget VBP
#
# , ,
#
# your PRP$
#
# PIN NN
#
# # NN
#
# is VBZ
#
# 3919 CD
#
# . .
#
# YOU PRP
#
# MAY MD
#
# ALL DT
#
# BEG VB
#
# @LucaHelvetica USR
#
# Exactly UH
#
# and CC
#
# thats DT
#
# why WRB
#
# i PRP
#
# have VBP
#
# qualified VBN
#
# every DT
#
# time NN
#
# i PRP
#
# have VBP
#
# said VBN
#
# that IN
#
# he PRP
#
# hasnt VBZ
#
# impressed VBN
#
# me PRP
#
# My PRP$
#
# dad NN
#
# laughed VBD
#
# when WRB
#
# he PRP
#
# read VBD
#
# about IN
#
# Linkin NNP
#
# Park NNP
#
# being VBG
#
# classified VBN
#
# under IN
#
# ' ''
#
# rap-rock'. NN
#
# I PRP
#
# hope VBP
#
# he PRP
#
# did VBD
#
# n't RB
#
# mean VB
#
# ' ''
#
# shit UH
#
# my PRP$
#
# son NN
#
# listens VBZ
#
# to'. TO
#
# Antick NNP
#
# Musings NNP
#
# post NN
#
# : :
#
# Book-A-Day NNP
#
# 2010 CD
#
# # NN
#
# 243 CD
#
# ( (
#
# 10/4 CD
#
# ) )
#
# -- :
#
# Gray NNP
#
# Horses NNP
#
# by IN
#
# Hope NNP
#
# Larson NNP
#
# http://bit.ly/as8fvc URL
#
# Amazing UH
#
# ! .
#
# RT RT
#
# @dailygalaxy USR
#
# Image NN
#
# of IN
#
# the DT
#
# Day NN
#
# : :
#
# A DT
#
# Ghostly NNP
#
# Reflection NNP
#
# Nebula NNP
#
# http://su.pr/1XBMfP URL
#
# @BexsterBexster USR
#
# @shinobi32768 USR
#
# I PRP
#
# 've VBP
#
# been VBN
#
# having VBG
#
# soup NN
#
# all DT
#
# week NN
#
# , ,
#
# do VBP
#
# n't RB
#
# really RB
#
# have VB
#
# a DT
#
# favourite NN
#
# . .
#
# It PRP
#
# 's VBZ
#
# starting VBG
#
# to TO
#
# taste VB
#
# pretty RB
#
# much RB
#
# the DT
#
# same JJ
#
# . .
#
# Where WRB
#
# It PRP
#
# Started VBD
#
# : :
#
# Guest NN
#
# Editor NN
#
# Warren NNP
#
# Ellis NNP
#
# Explains VBZ
#
# The DT
#
# Origin NN
#
# Of IN
#
# ' ''
#
# Red': NNP
#
# ... :
#
# next JJ
#
# two CD
#
# weeks NNS
#
# of IN
#
# coverage NN
#
# with IN
#
# five CD
#
# ... :
#
# http://bit.ly/bdoK3l URL
#
# I PRP
#
# like VBP
#
# when WRB
#
# it PRP
#
# rains VBZ
#
# . .
#
# volleyball NN
#
# tomorrow NN
#
# I PRP
#
# 'm VBP
#
# not RB
#
# an DT
#
# emotional JJ
#
# human NN
#
# being NN
#
# . .
#
# I PRP
#
# get VBP
#
# angry JJ
#
# before IN
#
# I PRP
#
# get VBP
#
# sad JJ
#
# . .
#
# And CC
#
# when WRB
#
# I PRP
#
# do VBP
#
# get VB
#
# sad JJ
#
# , ,
#
# It PRP
#
# 's VBZ
#
# often RB
#
# not RB
#
# that RB
#
# much JJ
#
# . .
#
# I PRP
#
# guess VBP
#
# I PRP
#
# 'm VBP
#
# kinda RB
#
# heartless JJ
#
# RT RT
#
# @TricycleTheatre USR
#
# : :
#
# v RB
#
# excited JJ
#
# that IN
#
# Director NN
#
# Nigel NNP
#
# Cole NNP
#
# will MD
#
# join VB
#
# our PRP$
#
# Made NNP
#
# in NNP
#
# Dagenham NNP
#
# Q__AND__A NN
#
# next JJ
#
# week NN
#
# ! .
#
# More JJR
#
# info NN
#
# here RB
#
# http://bit.ly/cNOeyS URL
#
# @acoyne USR
#
# but CC
#
# then RB
#
# what WP
#
# 's VBZ
#
# the DT
#
# point NN
#
# of IN
#
# twitter NNP
#
# if IN
#
# people NNS
#
# can MD
#
# just RB
#
# write VB
#
# nice JJ
#
# long JJ
#
# messages NNS
#
# ? .
#
# it PRP
#
# would MD
#
# lose VB
#
# its PRP$
#
# critical JJ
#
# advantage NN
#
# . .
#
# RT RT
#
# @SPN_minion USR
#
# : :
#
# #Supernatural HT
#
# is VBZ
#
# like IN
#
# a DT
#
# vitamin NN
#
# , ,
#
# you PRP
#
# should MD
#
# take VB
#
# at IN
#
# least JJS
#
# one CD
#
# dose NN
#
# every DT
#
# day NN
#
# ! .
#
# After IN
#
# so RB
#
# longggggg JJ
#
# , ,
#
# I PRP
#
# 'm VBP
#
# finally RB
#
# outta IN
#
# the DT
#
# overweight NN
#
# category NN
#
# ! .
#
# But CC
#
# i PRP
#
# still RB
#
# hate VBP
#
# my PRP$
#
# body NN
#
# . .
#
# Sighhhhh UH
#
# ~ :
#
# Just RB
#
# 5 CD
#
# days NNS
#
# until IN
#
# our PRP$
#
# huge JJ
#
# Twice NNP
#
# Loved NNP
#
# Boutique NNP
#
# Breast NNP
#
# Cancer NNP
#
# Awareness NNP
#
# Bag NNP
#
# Sale NN
#
# Savings NNS
#
# Event NN
#
# ! .
#
# ! .
#
# We PRP
#
# 've VBP
#
# got VBN
#
# a DT
#
# tent NN
#
# ... :
#
# http://fb.me/EXtZkGSX URL
#
# Jiaaah NNP
#
# .. :
#
# Ky NNP
#
# barang VBG
#
# aja JJ
#
# maen NN
#
# nitip NN
#
# ".. O
#
# Hahaha UH
#
# .. :
#
# Udh NNP
#
# jul NN
#
# .. :
#
# Galakin NNP
#
# aja UH
#
# .. :
#
# Wkwkwk NNP
#
# RT RT
#
# @riesranty USR
#
# : :
#
# @azkuro USR
#
# kak JJ
#
# ajul NN
#
# , ,
#
# titip NNP
#
# ... :
#
# http://mtw.tl/lkfslx URL
#
# Mum NN
#
# just RB
#
# told VBD
#
# me PRP
#
# she PRP
#
# bought VBD
#
# me PRP
#
# an DT
#
# alice NNP
#
# wig NN
#
# and CC
#
# an DT
#
# eclipse NNP
#
# advent NNP
#
# calendar NN
#
# , ,
#
# could MD
#
# this DT
#
# day NN
#
# get VB
#
# better JJR
#
# ? .
#
# He PRP
#
# did VBD
#
# okay JJ
#
# when WRB
#
# he PRP
#
# played VBD
#
# . .
#
# RT RT
#
# @Itsgreat2bme USR
#
# : :
#
# @bmoreumissedit USR
#
# It PRP
#
# was VBD
#
# no DT
#
# game NN
#
# for IN
#
# Adam NNP
#
# , ,
#
# what WP
#
# is VBZ
#
# it PRP
#
# called VBD
# by-week NN
#
# ? .
#
# How WRB
#
# did VBD
#
# little JJ
#
# G NNP
#
# do VBP
#
# ? .
#
# " ''
#
# when WRB
#
# ur PRP
#
# feelin VBG
#
# good JJ
#
# in IN
#
# somebodys NN
#
# spot NN
#
# gettin VBG
#
# hot JJ
#
# dont VB
#
# stop VB
#
# .. :
#
# just RB
#
# dont VB
#
# think VB
#
# im PRP
#
# not RB
#
# .. :
#
# cuz IN
#
# im PRP
#
# out IN
#
# gettin VBG
#
# mineS NNS
#
# "! .
#
# realest JJS
#
# throwback NN
#
# of IN
#
# all DT
#
# time NN
#
# @IAMtheCOMMODORE USR
#
# Today NN
#
# is VBZ
#
# my PRP$
#
# 20th JJ
#
# birthday NN
#
# and CC
#
# it PRP
#
# would MD
#
# mean VB
#
# the DT
#
# world NN
#
# to TO
#
# me PRP
#
# if IN
#
# I PRP
#
# got VBD
#
# an DT
#
# @reply NN
#
# from IN
#
# you PRP
#
# today NN
#
# ! .
#
# &lt; UH
#
# 3 UH
#
# Happy JJ
#
# Monday NNP
#
# to TO
#
# Everyone NN
#
# ! .
#
# #education HT
#
# can MD
#
# never RB
#
# be VB
#
# taken VBN
#
# away RB
#
# ... :
#
# go VB
#
# follow VB
#
# your PRP$
#
# #dreams HT
#
# @taylorrhicks USR
#
# Thunder NN
#
# , ,
#
# lightening NN
#
# , ,
#
# first JJ
#
# rain NN
#
# we PRP
#
# 've VBP
#
# had VBN
#
# in IN
#
# months NNS
#
# ... :
#
# love VBP
#
# it PRP
#
# ! .
#
# Chukchansi NNP
#
# had VBD
#
# a DT
#
# pow NN
#
# wow NN
#
# this DT
#
# weekend NN
#
# . .
#
# Think VBP
#
# someone NN
#
# did VBD
#
# a DT
#
# ... :
#
# Got VBD
#
# another DT
#
# two CD
#
# box NN
#
# of IN
#
# chocolate NN
#
# from IN
#
# sister NN
#
# . .
#
# . .
#
# Rewind VB
#
# the DT
#
# 1st CD
#
# time NN
#
# I PRP
#
# gave VBD
#
# you PRP
#
# a DT
#
# bar NN
#
# of IN
#
# chocolate NN
#
# . .
#
# . .
#
# Everything NN
#
# pratically RB
#
# remind VBP
#
# me PRP
#
# of IN
#
# you PRP
#
# ? .
#
# @MzStarrBurst USR
#
# You PRP
#
# doing VBG
#
# a DT
#
# person NN
#
# 's POS
#
# makeup NN
#
# does VBZ
#
# n't RB
#
# dictate VB
#
# what WP
#
# medication NN
#
# they PRP
#
# may MD
#
# receive VB
#
# . .
#
# That DT
#
# 's VBZ
#
# my PRP$
#
# point NN
#
# . .
#
# Do VBP
#
# you PRP
#
# want VBP
#
# to TO
#
# learn VB
#
# how WRB
#
# to TO
#
# get VB
#
# rooms NNS
#
# at IN
#
# the DT
#
# Marriott NNP
#
# for IN
#
# $35 CD
#
# a DT
#
# night NN
#
# , ,
#
# all DT
#
# year NN
#
# long JJ
#
# ? .
#
# Check VB
#
# this DT
#
# out RP
#
# ! .
#
# ------ SYM
#
# &gt; SYM
#
# http://bit.ly/cL9IwC URL
#
# RT RT
#
# @IronRangeMN USR
#
# : :
#
# October NNP
#
# Iron NNP
#
# Range NNP
#
# eNews NNS
#
# and CC
#
# Specials NNS
#
# http://conta.cc/9N6D15 URL
#
# via HT
#
# #constantcontact HT
#
# Dierks NNP
#
# Bentley NNP
#
# Admits VBZ
#
# He PRP
#
# Snuck VBP
#
# Into IN
#
# Grand NNP
#
# Ole NNP
#
# Opry NNP
#
# Before IN
#
# He PRP
#
# Made VBD
#
# It PRP
#
# Big JJ
#
# : :
#
# Just RB
#
# days NNS
#
# after IN
#
# join NN
#
# ... :
#
# http://bit.ly/9LJLHE URL
#
# Antick NNP
#
# Musings NNP
#
# post NN
#
# : :
#
# Reviewing VBG
#
# the DT
#
# Mail NN
#
# : :
#
# Week NN
#
# of IN
#
# 10/2 CD
#
# http://bit.ly/9PIm5E URL
#
# Trying VBG
#
# Something NN
#
# New JJ
#
# In IN
#
# Bed NN
#
# ( (
#
# You PRP
#
# Game JJ
#
# ? .
#
# ) )
#
# : :
#
# Someone NN
#
# wrote VBD
#
# me PRP
#
# last JJ
#
# week NN
#
# about IN
#
# wanting VBG
#
# to TO
#
# role VB
#
# play VB
#
# . .
#
# Her PRP$
#
# husband NN
#
# is VBZ
#
# a DT
#
# ... :
#
# http://yhoo.it/bX9l33 URL
#
# Our PRP$
#
# October NNP
#
# issue NN
#
# drops VBZ
#
# today NN
#
# ! .
#
# Pick VB
#
# up RP
#
# a DT
#
# copy NN
#
# in IN
#
# your PRP$
#
# area NN
#
# for IN
#
# birthday NN
#
# party NN
#
# ideas NNS
#
# and CC
#
# resources NNS
#
# , ,
#
# tons NNS
#
# of IN
#
# ... :
#
# http://fb.me/HsqX911j URL
#
# Today NN
#
# has VBZ
#
# been VBN
#
# a DT
#
# GREAT JJ
#
# day NN
#
# __AND__ CC
#
# it PRP
#
# just RB
#
# keeps VBZ
#
# getting VBG
#
# better RB
#
# !!! .
#
# Thank VB
#
# You PRP
#
# Lord NNP
#
# ! .
#
# Big JJ
#
# news NN
#
# , ,
#
# indeed RB
#
# ! .
#
# RT RT
#
# @AlexPappasDC USR
#
# Big JJ
#
# news NN
#
# at IN
#
# TheDC NNP
#
# RT RT
#
# @mkhammer USR
#
# Start VB
#
# new JJ
#
# job NN
#
# doing VBG
#
# video NN
#
# @DailyCaller USR
#
# tomorrow NN
#
# ! .
#
# http://is.gd/fKm4j URL
#
# I PRP
#
# 'm VBP
#
# so RB
#
# addicted VBN
#
# to TO
#
# Twitter NNP
#
# now RB
#
# that IN
#
# I PRP
#
# can MD
#
# tweet VB
#
# all DT
#
# the DT
#
# time NN
#
# . .
#
# Not RB
#
# good JJ
#
# . .
#
# @DORSEY33 USR
#
# lol UH
#
# aw UH
#
# . .
#
# i PRP
#
# thought VBD
#
# u PRP
#
# was VBD
#
# talkin VBG
#
# bout IN
#
# another DT
#
# time NN
#
# . .
#
# nd CC
#
# i PRP
#
# dnt VBP
#
# see VB
#
# u PRP
#
# either RB
#
# ! .
#
# Deez DT
#
# niggaz NNS
#
# now RB
#
# a DT
#
# days NNS
#
# is VBZ
#
# strate JJ
#
# clowns NNS
#
# ... :
#
# 85% CD
#
# of IN
#
# deez DT
#
# niggaz NNS
#
# ai VBP
#
# n't RB
#
# shit JJ
#
# wit IN
#
# out IN
#
# eachother NN
#
# .. :
#
# #bitchmade HT
#
# @Bibhu2109 USR
#
# No UH
#
# . .
#
# He PRP
#
# 's VBZ
#
# gonna VBG
#
# run VB
#
# out IN
#
# of IN
#
# money NN
#
# some DT
#
# day NN
#
# :P UH
#
# @SincerelyKRenee USR
#
# but CC
#
# u PRP
#
# can MD
#
# just RB
#
# get VB
#
# her PRP
#
# shit NN
#
# today NN
#
# n CC
#
# do VBP
#
# n't RB
#
# forget VB
#
# goosh UH
#
# we PRP
#
# know VBP
#
# how WRB
#
# u PRP
#
# get VBP
#
# b4 IN
#
# I PRP
#
# make VBP
#
# her PRP
#
# beat VBP
#
# on IN
#
# u PRP
#
# Forbidden NNP
#
# Fruit NNP
#
# : :
#
# How WRB
#
# to TO
#
# Deal VB
#
# When WRB
#
# Your PRP$
#
# Crush NN
#
# Is VBZ
#
# Taken VBN
#
# : :
#
# http://yhoo.it/aFG5Ue URL
#
# RT RT
#
# @MyssLidia USR
#
# : :
#
# If IN
#
# u PRP
#
# call VBP
#
# someone NN
#
# 5x NN
#
# 's VBZ
#
# a DT
#
# day NN
#
# and CC
#
# they PRP
#
# do VBP
#
# n't RB
#
# answer VB
#
# , ,
#
# do VBP
#
# u PRP
#
# not RB
#
# get VB
#
# a DT
#
# hint NN
#
# that IN
#
# MAYBE RB
#
# they PRP
#
# just RB
#
# do VBP
#
# n't RB
#
# wanna VBP
#
# talk VB
#
# to TO
#
# u PRP
#
# !!!!! .
#
# 787
# ['@paulwalk', 'It', "'s", 'the', 'view', 'from', 'where', 'I', "'m", 'living', 'for', 'two', 'weeks', '.', 'Empire', 'State', 'Building', '=', 'ESB', '.', 'Pretty', 'bad', 'storm', 'here', 'last', 'evening', '.']
# ['USR', 'PRP', 'VBZ', 'DT', 'NN', 'IN', 'WRB', 'PRP', 'VBP', 'VBG', 'IN', 'CD', 'NNS', '.', 'NNP', 'NNP', 'NNP', 'SYM', 'NNP', '.', 'RB', 'JJ', 'NN', 'RB', 'JJ', 'NN', '.']

# %% [markdown]
# ## Tagging the corpus and evaluating it

# %% [markdown]
# Now that we read our test set, let's try to tag it using our HMM tagger trained before.

# %%
predictions = []
for sent in test_inputs:
    encoded_sent = [word_numbers[w] for w in sent]
    pred = viterbi((pi, A, O), encoded_sent)
    predictions.append([tag_names[i] for i in pred])

# %% [markdown]
# This will raise an error due to an OOV word. A simple way to deal with OOV's is to smooth the counts in the emission matrix. Let's do that.

# %%
# Add an OOV token to our dictionary. Let's call it '<unk>'
unk_index = len(word_numbers)
word_numbers.setdefault('<unk>', unk_index)
word_names.append('<unk>')

V = len(word_numbers)

# initalise
eps = 0.1
O = eps * np.ones((S, V))

# add one smoothing
O += 1.0

# count
for sent in num_corpus:
    for word, tag in sent:
        O[tag, word] += 1
 
# normalise
for s in range(S):
    O[s,:] /= np.sum(O[s,:])

# %% [markdown]
# Now to tag the sentence, we first replace any OOV words with our '<unk>' token.

# %%
predictions = []
for sent in test_inputs:
    encoded_sent = []
    for word in sent:
        if word in word_numbers:
            encoded_sent.append(word_numbers[word])
        else:
            encoded_sent.append(word_numbers['<unk>'])
    pred, _ = viterbi((pi, A, O), encoded_sent)
    #predictions.append([tag_names[i] for i in predicted]
    predictions.append(pred)
    

print predictions[0]
print('%20s\t%5s\t%5s' % ('TOKEN', 'TRUE', 'PRED'))
for wi, ti, predi in zip(test_inputs[0], test_outputs[0], predictions[0]):
    print('%20s\t%5s\t%5s' % (wi, ti, tag_names[predi]))

# %% [markdown]
# There are quite a few errors here, much more than in the previous workshop example. Let's try to quantify this in terms of accuracy, so we can compare with PTB numbers.

# %%
from sklearn.metrics import accuracy_score as acc

# flat our data into single lists
all_test_tags = [tag for tags in test_outputs for tag in tags]
# for predictions, we need to obtain the original tag from the index
all_pred_tags = [tag_names[tag] for tags in predictions for tag in tags]

print acc(all_test_tags, all_pred_tags)

# %% [markdown]
# 51.9% accuracy is quite low. Compare this to the performance on Penn Treebank, which can reach 96.7% accuracy. One reason for such low numbers is the fact we are training only on a subset of Penn Treebank (since it is freely available on NLTK). But even state-of-the-art POS taggers reach only 80% accuracy on this dataset (Ritter et al., EMNLP 2011).
#
# Notice that the twitter test set has some tags which are not defined in PTB, such as "USR" for user mentions (@paulwalk, in the example above). This means that these additional tags will never get predicted using the current tagger. Can you come up with a solution for that?
